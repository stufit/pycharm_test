# %% [markdown]
# ### Cine21 영화배우 정보 웹스크래핑
# 1. site 주소: http://www.cine21.com/rank/person/
# 2. Request URL : http://www.cine21.com/rank/person/content
#    * 크롬 개발자 도구의 network탭에서 xhr 인 것만 필터링
# 3. Request Method: POST
# 4. Form Data
#     * section: actor
#     * period_start: 2020-09
#     * gender: all
#     * page: 1
#
# 5. 2년치 데이터를 한꺼번에 스크래핑 해서 actors.json파일로 저장

# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

# %% [markdown]
# ### 1단계
# * 1 page 7명의 이름,흥행지수,랭킹과 상세정보 추출

# %% [markdown]
# ### 정규표현식(regular expression) -> regExr(https://regexr.com)사이트 사용
# * \n은 word를 표현하며 알파벳 +숫자+ _중의 한 문자임을 의마한다.
# * 문자가 출현한 횟수를 나타낼 때
# <pre>
#     *(아스타): 0~n, +(플러스): 1~n, ?(물음표): 0(zero) or 1
# </pre>
# * 정규표현식에서 특수문자를 사용할때는 특수문자 앞에 \(백슬레시)를 반드시 주어야 한다.
# * .(period)는 줄바꿈 문자(\n)를 제외한 모든 글자1개를 의마한다.
# * Greedy VS Non-Greedy
#     - Greedy (.*) : 모든 태그가 다 선택됨
#     - Non-Greedy(.*?) : 첫 번째 매칭되는 태그만 선택됨
# * [\n\r\t] : \n,\r,\t 중에 하나만 찾는다
#     - re.compile('[\n\r\t]')는 해당 정규표현식을 찾아주는 컴파일러를 생성한다.
#     - compile 함수내의 정규표현식 앞에는 항상 r을 붙인다.

# %%
req_url = 'http://www.cine21.com/rank/person/content'
req_param ={
    'section': 'actor',
    'period_start': '2020-09',
    'gender': 'all',
    'page': 1
}
res = requests.post(req_url, data=req_param)
print(res.status_code)
if res.ok:
    soup=BeautifulSoup(res.text,'html.parser')
#     print(soup.select('li.people_li div.name'))
    
    for li_tag in soup.select('li.people_li'):
#         print(li_tag.select('div.name'))
        div_tag = li_tag.select_one('div.name')
#         print(div_tag.select_one('a')['href'])
        detail_url = div_tag.select_one('a')['href']
        detail_url = urljoin(req_url,detail_url)
        name=div_tag.text
        #정규표현식 사용하여 이름 옆에 (n편) 삭제
        result = re.sub('\(\w*\)','',name)
#         print(result, detail_url)
        
        res = requests.get(detail_url)
        if res.ok:
            soup = BeautifulSoup(res.text,'html.parser')
            for li_tag in soup.select('ul.default_info li'):
                actor_dict_key = li_tag.select_one('span.tit').text
#                 print(li_tag)
#                 <li><span class="tit">직업</span>배우</li> => 치환된 결과 <li>배우</li>
                result = re.sub('<span.*>.*<\/span>','',str(li_tag))
#                 <li>배우</li> => '배우'만 나오게 바꿔줌
                actor_dict_value = re.sub('<.*?>','',result)
#                 print(actor_dict_key,actor_dict_value)
        
                regex = re.compile(r'[\n\r\t]')
                actor_dict_value = regex.sub('',actor_dict_value)
                print(actor_dict_key,actor_dict_value)
# Out:
# 200
# 직업 배우
# 생년월일 1967-04-27
# 성별 남
# 신장/체중 177cm, 78kg
# 학교 유한대학 기계설계학
# 직업 배우
# 생년월일 1978-06-28
# 성별 여
# 홈페이지 https://twitter.com/hajiwon1023https://instagram.com/hajiwon1023
# 신장/체중 168cm, 45kg
# 학교 단국대학교 연극영화학 학사
# 취미 만화책보기, 소품만들기, 청소하기
# 특기 검도, 골프, 승마, 재즈댄스, 장구춤
# 직업 배우
# 생년월일 1971-01-10
# 성별 남
# 신장/체중 180cm
# 학교 서울예술대학 연극과
# 소속사 DMS커뮤니케이션즈
# 다른 이름 엄홍식
# 직업 배우
# 생년월일 1986-10-06
# 성별 남
# 홈페이지 https://www.instagram.com/hongsick/https://twitter.com/seeksik
# 신장/체중 178cm, 60kg
# 학교 단국대학교 연극
# 취미 피아노 연주, 인터넷 게임, 영화, 음악감상
# 특기 스노우보드, 수영
# 직업 배우
# 생년월일 2012-03-12
# 성별 여
# 직업 배우
# 생년월일 1973-06-03
# 성별 남
# 직업 배우
# 생년월일 1941-11-30
# 성별 여
# 홈페이지 http://www.namuni.kr/
# 학교 창덕여자고등학교

# %% [markdown]
# ### 2단계
# * 1 page 7명의 이름,흥행지수,랭킹과 상세정보 추출
# * 배우의 정보는 dict에 저장하고, dict를 list에 저장한다.

# %%
req_url = 'http://www.cine21.com/rank/person/content'
req_param ={
    'section': 'actor',
    'period_start': '2020-09',
    'gender': 'all',
    'page': 1
}
res = requests.post(req_url, data=req_param)
print(res.status_code)
if res.ok:
    soup=BeautifulSoup(res.text,'html.parser')
    
    actor_detail_list=[]
    
    actor_li_tag= soup.select('li.people_li')
    hits = soup.select('ul.num_info>li>strong')
#     print(len(actor_li_tag),len(hits))
    
    for li_tag in actor_li_tag:
        actor_detail_dict={}
        
        
        div_tag = li_tag.select_one('div.name')
        #상세페이지 url 추출
        detail_url = div_tag.select_one('a')['href']
        detail_url = urljoin(req_url,detail_url)
        #배우이름 추출
        name=div_tag.text
        #성동일(1편)=>성동일 로 바꿔줌
        actor_name = re.sub('\(\w*\)','',name)
        actor_detail_dict['배우이름']= actor_name
        
        #순위(ranking)추출
#         print(li_tag.select_one('span.grade'))
        actor_ranking = li_tag.select_one('span.grade').text
        actor_detail_dict['랭킹']=int(actor_ranking)
        
        #흥행지수 추출
        actor_hit = li_tag.select_one('ul.num_info>li>strong').text
        actor_detail_dict['흥행지수']=actor_hit.replace('.','')
                                
#         print(actor_detail_dict)
        
        #상세정보 페이지에 요청 보내기
        res = requests.get(detail_url)
        if res.ok:
            soup = BeautifulSoup(res.text,'html.parser')
            
            #기본정보
            for li_tag in soup.select('ul.default_info li'):
                actor_dict_key = li_tag.select_one('span.tit').text
                result = re.sub('<span.*>.*<\/span>','',str(li_tag))
                actor_dict_value = re.sub('<.*?>','',result)
                regex = re.compile(r'[\n\r\t]')
                actor_dict_value = regex.sub('',actor_dict_value)
                
                #상세페이지에서 추출한 key와 value를 dict에 저장
                actor_detail_dict[actor_dict_key] = actor_dict_value
            
            #참여작품
            movie_title_list=[]
            for movie_li_tag in soup.select('ul.part_works li'):
                movie_title = movie_li_tag.select_one('span.tit').text
                movie_title_list.append(movie_title)
                
#             print(movie_title_list)
            actor_detail_dict['출연영화']=movie_title_list
            
            #상세정보 담은 dict를 list에 추가함
            actor_detail_list.append(actor_detail_dict)
            
print(actor_detail_list[0:2])
# Out:
# 200
# [{'배우이름': '성동일', '랭킹': 1, '흥행지수': '139,484', '직업': '배우', '생년월일': '1967-04-27', '성별': '남', '신장/체중': '177cm, 78kg', '학교': '유한대학 기계설계학', '출연영화': ['방법', '어쩌다 가족', '바퀴 달린 집']}, {'배우이름': '하지원', '랭킹': 2, '흥행지수': '104,613', '직업': '배우', '생년월일': '1978-06-28', '성별': '여', '홈페이지': 'https://twitter.com/hajiwon1023https://instagram.com/hajiwon1023', '신장/체중': '168cm, 45kg', '학교': '단국대학교 연극영화학 학사', '취미': '만화책보기, 소품만들기, 청소하기', '특기': '검도, 골프, 승마, 재즈댄스, 장구춤', '출연영화': ['담보', '초콜릿', '갈릴레오 : 깨어난 우주']}]

# %% [markdown]
# ### 3단계
# * 1,2,3 page 21명의 이름,흥행지수,랭킹과 상세정보 추출
# * 배우의 정보는 dict에 저장하고, dict를 list에 저장한다.

# %%
req_url = 'http://www.cine21.com/rank/person/content'
req_param ={
    'section': 'actor',
    'period_start': '2020-09',
    'gender': 'all'
}

#21명의 배우 dict를 저장할 리스트
actor_detail_list=[]

for page in range(1,10):
    req_param['page'] = page
    res = requests.post(req_url, data=req_param)
    print(f'--->{page}페이지 출력됨')
    if res.ok:
        soup=BeautifulSoup(res.text,'html.parser')
        actor_li_tag= soup.select('li.people_li')
        for idx,li_tag in enumerate(actor_li_tag,1):
            actor_detail_dict={}
            div_tag = li_tag.select_one('div.name')
            #상세페이지 url 추출
            detail_url = div_tag.select_one('a')['href']
            detail_url = urljoin(req_url,detail_url)
            #배우이름 추출
            name=div_tag.text
            #성동일(1편)=>성동일 로 바꿔줌
            actor_name = re.sub('\(\w*\)','',name)
            actor_detail_dict['배우이름']= actor_name
            print(f'======>{idx}:{actor_name} 배우')
            #순위(ranking)추출
    #         print(li_tag.select_one('span.grade'))
            actor_ranking = li_tag.select_one('span.grade').text
            actor_detail_dict['랭킹']=int(actor_ranking)

            #흥행지수 추출
            actor_hit = li_tag.select_one('ul.num_info>li>strong').text
            actor_detail_dict['흥행지수']=actor_hit.replace('.','')

    #         print(actor_detail_dict)

            #상세정보 페이지에 요청 보내기
            res = requests.get(detail_url)
            if res.ok:
                soup = BeautifulSoup(res.text,'html.parser')

                #기본정보
                for li_tag in soup.select('ul.default_info li'):
                    actor_dict_key = li_tag.select_one('span.tit').text
                    result = re.sub('<span.*>.*<\/span>','',str(li_tag))
                    actor_dict_value = re.sub('<.*?>','',result)
                    regex = re.compile(r'[\n\r\t]')
                    actor_dict_value = regex.sub('',actor_dict_value)

                    #상세페이지에서 추출한 key와 value를 dict에 저장
                    actor_detail_dict[actor_dict_key] = actor_dict_value

                #참여작품
                movie_title_list=[]
                for movie_li_tag in soup.select('ul.part_works li'):
                    movie_title = movie_li_tag.select_one('span.tit').text
                    movie_title_list.append(movie_title)

    #             print(movie_title_list)
                actor_detail_dict['출연영화']=movie_title_list

                #상세정보 담은 dict를 list에 추가함
                actor_detail_list.append(actor_detail_dict)
print(len(actor_detail_list))
# Out:
# --->1페이지 출력됨
# ======>1:성동일 배우
# ======>2:하지원 배우
# ======>3:김희원 배우
# ======>4:유아인 배우
# ======>5:박소이 배우
# ======>6:유재명 배우
# ======>7:나문희 배우
# --->2페이지 출력됨
# ======>1:이희준 배우
# ======>2:김호중 배우
# ======>3:고아성 배우
# ======>4:이솜 배우
# ======>5:최원영 배우
# ======>6:박혜수 배우
# ======>7:곽도원 배우
# --->3페이지 출력됨
# ======>1:김대명 배우
# ======>2:문승아 배우
# ======>3:조현철 배우
# ======>4:김종수 배우
# ======>5:김상호 배우
# ======>6:신민아 배우
# ======>7:장혁 배우
# --->4페이지 출력됨
# ======>1:김원해 배우
# ======>2:황정민 배우
# ======>3:박지영 배우
# ======>4:이선호 배우
# ======>5:유진우 배우
# ======>6:김현수 배우
# ======>7:배해선 배우
# --->5페이지 출력됨
# ======>1:손현주 배우
# ======>2:백현진 배우
# ======>3:이유영 배우
# ======>4:조재윤 배우
# ======>5:정만식 배우
# ======>6:이정재 배우
# ======>7:RM 배우
# --->6페이지 출력됨
# ======>1:임영웅 배우
# ======>2:이성욱 배우
# ======>3:신동미 배우
# ======>4:이정현 배우
# ======>5:진 배우
# ======>6:영탁 배우
# ======>7:이나경 배우
# --->7페이지 출력됨
# ======>1:신승환 배우
# ======>2:이주영 배우
# ======>3:이진주 배우
# ======>4:홍시호 배우
# ======>5:슈가 배우
# ======>6:김성오 배우
# ======>7:이찬원 배우
# --->8페이지 출력됨
# ======>1:이한서 배우
# ======>2:제이홉 배우
# ======>3:이규형 배우
# ======>4:이민혁 배우
# ======>5:문남숙 배우
# ======>6:서영희 배우
# ======>7:박정민 배우
# --->9페이지 출력됨
# ======>1:정동원 배우
# ======>2:장민혁 배우
# ======>3:김창옥 배우
# ======>4:조현정 배우
# ======>5:지민 배우
# ======>6:김보영 배우
# ======>7:양동근 배우
# 63

# %% [markdown]
# ### 4단계
# * 모든 page의 배우이름,흥행지수,랭킹과 상세정보 추출
# * 배우의 정보는 dict에 저장하고, dict를 list에 저장한다.
# * itertools 모듈의 count()함수를 사용하여 무한루프
#     - 무한루프를 빠져나올 수 있는 조건을 반드시 주어야 한다.

# %%
from itertools import count

req_url = 'http://www.cine21.com/rank/person/content'
req_param ={
    'section': 'actor',
    'period_start': '2018-10',
    'gender': 'all'
}

#21명의 배우 dict를 저장할 리스트
actor_detail_list=[]

for page in count(1):
    req_param['page'] = page
    res = requests.post(req_url, data=req_param)
    if page %50 ==0:
        print(f'--->{page}페이지 출력됨')
    if res.ok:
        soup=BeautifulSoup(res.text,'html.parser')
        actor_li_tag= soup.select('li.people_li')
        
        #해당 page가 없으면 루프 탈출
        if len(actor_li_tag)==0:
            break
            
        for idx,li_tag in enumerate(actor_li_tag,1):
            actor_detail_dict={}
            div_tag = li_tag.select_one('div.name')
            #상세페이지 url 추출
            detail_url = div_tag.select_one('a')['href']
            detail_url = urljoin(req_url,detail_url)
            #배우이름 추출
            name=div_tag.text
            #성동일(1편)=>성동일 로 바꿔줌
            actor_name = re.sub('\(\w*\)','',name)
            actor_detail_dict['배우이름']= actor_name
            print(f'======>{idx}:{actor_name} 배우')
            #순위(ranking)추출
    #         print(li_tag.select_one('span.grade'))
            actor_ranking = li_tag.select_one('span.grade').text
            actor_detail_dict['랭킹']=int(actor_ranking)

            #흥행지수 추출
            actor_hit = li_tag.select_one('ul.num_info>li>strong').text
            actor_detail_dict['흥행지수']=actor_hit.replace('.','')

    #         print(actor_detail_dict)

            #상세정보 페이지에 요청 보내기
            res = requests.get(detail_url)
            if res.ok:
                soup = BeautifulSoup(res.text,'html.parser')

                #기본정보
                for li_tag in soup.select('ul.default_info li'):
                    actor_dict_key = li_tag.select_one('span.tit').text
                    result = re.sub('<span.*>.*<\/span>','',str(li_tag))
                    actor_dict_value = re.sub('<.*?>','',result)
                    regex = re.compile(r'[\n\r\t]')
                    actor_dict_value = regex.sub('',actor_dict_value)

                    #상세페이지에서 추출한 key와 value를 dict에 저장
                    actor_detail_dict[actor_dict_key] = actor_dict_value

                #참여작품
                movie_title_list=[]
                for movie_li_tag in soup.select('ul.part_works li'):
                    movie_title = movie_li_tag.select_one('span.tit').text
                    movie_title_list.append(movie_title)

    #             print(movie_title_list)
                actor_detail_dict['출연영화']=movie_title_list

                #상세정보 담은 dict를 list에 추가함
                actor_detail_list.append(actor_detail_dict)
print(len(actor_detail_list))
# Out:
# ======>1:이병헌 배우
# ======>2:진선규 배우
# ======>3:하정우 배우
# ======>4:마동석 배우
# ======>5:이하늬 배우
# ======>6:류승룡 배우
# ======>7:유해진 배우
# ======>1:박정민 배우
# ======>2:황정민 배우
# ======>3:송강호 배우
# ======>4:조진웅 배우
# ======>5:신하균 배우
# ======>6:조우진 배우
# ======>7:이동휘 배우
# ======>1:이정재 배우
# ======>2:전혜진 배우
# ======>3:염정아 배우
# ======>4:공명 배우
# ======>5:장혜진 배우
# ======>6:이선균 배우
# ======>7:유아인 배우
# ======>1:조정석 배우
# ======>2:오정세 배우
# ======>3:이성민 배우
# ======>4:최우식 배우
# ======>5:박소담 배우
# ======>6:김윤석 배우
# ======>7:공효진 배우
# ======>1:김의성 배우
# ======>2:김아중 배우
# ======>3:김무열 배우
# ======>4:강기영 배우
# ======>5:곽도원 배우
# ======>6:성동일 배우
# ======>7:김종수 배우
# ======>1:배수지 배우
# ======>2:권해효 배우
# ======>3:임윤아 배우
# ======>4:주지훈 배우
# ======>5:이희준 배우
# ======>6:라미란 배우
# ======>7:이봉련 배우
# ======>1:고두심 배우
# ======>2:장기용 배우
# ======>3:권상우 배우
# ======>4:윤경호 배우
# ======>5:박인환 배우
# ======>6:최유화 배우
# ======>7:허준호 배우
# ======>1:김홍파 배우
# ======>2:조여정 배우
# ======>3:송영규 배우
# ======>4:박지환 배우
# ======>5:정해인 배우
# ======>6:강동원 배우
# ======>7:이서진 배우
# ======>1:정유미 배우
# ======>2:김지영 배우
# ======>3:류준열 배우
# ======>4:김성오 배우
# ======>5:김희원 배우
# ======>6:이정현 배우
# ======>7:허성태 배우
# ======>1:김민재 배우
# ======>2:문정희 배우
# ======>3:송영창 배우
# ======>4:박성웅 배우
# ======>5:공유 배우
# ======>6:정우성 배우
# ======>7:조한철 배우
# ======>1:장영남 배우
# ======>2:김래원 배우
# ======>3:정지소 배우
# ======>4:정만식 배우
# ======>5:이레 배우
# ======>6:김종구 배우
# ======>7:배성우 배우
# ======>1:양현민 배우
# ======>2:이재인 배우
# ======>3:염혜란 배우
# ======>4:박서준 배우
# ======>5:김상중 배우
# ======>6:설경구 배우
# ======>7:유지태 배우
# ======>1:우현 배우
# ======>2:김성규 배우
# ======>3:김미경 배우
# ======>4:김병순 배우
# ======>5:박신혜 배우
# ======>6:이경영 배우
# ======>7:이광수 배우
# ======>1:김지수 배우
# ======>2:송지효 배우
# ======>3:김소진 배우
# ======>4:황효은 배우
# ======>5:유승목 배우
# ======>6:성유빈 배우
# ======>7:정현준 배우
# ======>1:공민정 배우
# ======>2:박해준 배우
# ======>3:김남길 배우
# ======>4:김재영 배우
# ======>5:하지원 배우
# ======>6:우도환 배우
# ======>7:허준석 배우
# ======>1:김성균 배우
# ======>2:최성은 배우
# ======>3:손종학 배우
# ======>4:최덕문 배우
# ======>5:구교환 배우
# ======>6:나문희 배우
# ======>7:엄정화 배우
# ======>1:윤제문 배우
# ======>2:송하윤 배우
# ======>3:류승범 배우
# ======>4:박성연 배우
# ======>5:정민성 배우
# ======>6:고아성 배우
# ======>7:김향기 배우
# ======>1:정준호 배우
# ======>2:이준혁 배우
# ======>3:김예원 배우
# ======>4:김혜수 배우
# ======>5:강신일 배우
# ======>6:이규형 배우
# ======>7:최민철 배우
# ======>1:윤계상 배우
# ======>2:정웅인 배우
# ======>3:이솜 배우
# ======>4:김성철 배우
# ======>5:안재홍 배우
# ======>6:김수현 배우
# ======>7:황우슬혜 배우
# ======>1:양정화 배우
# ======>2:이다윗 배우
# ======>3:유재명 배우
# ======>4:박철민 배우
# ======>5:정인겸 배우
# ======>6:박성일 배우
# ======>7:이성경 배우
# ======>1:장소연 배우
# ======>2:강소라 배우
# ======>3:김선영 배우
# ======>4:한정현 배우
# ======>5:이이경 배우
# ======>6:전도연 배우
# ======>7:김새벽 배우
# ======>1:허동원 배우
# ======>2:현빈 배우
# ======>3:박혜수 배우
# ======>4:한석규 배우
# ======>5:RM 배우
# ======>6:도경수 배우
# ======>7:조현정 배우
# ======>1:진영 배우
# ======>2:김태훈 배우
# ======>3:김혜준 배우
# ======>4:윤상현 배우
# ======>5:전배수 배우
# ======>6:최민식 배우
# ======>7:주민경 배우
# ======>1:정진영 배우
# ======>2:엄효섭 배우
# ======>3:박진주 배우
# ======>4:배유람 배우
# ======>5:이지원 배우
# ======>6:박희순 배우
# ======>7:최귀화 배우
# ======>1:장진희 배우
# ======>2:이상윤 배우
# ======>3:안성기 배우
# ======>4:이성욱 배우
# ======>5:배정남 배우
# ======>6:허진 배우
# ======>7:김고은 배우
# ======>1:김윤성 배우
# ======>2:진 배우
# ======>3:이선빈 배우
# ======>4:차승원 배우
# ======>5:지승현 배우
# ======>6:박영규 배우
# ======>7:박근형 배우
# ======>1:김태우 배우
# ======>2:신구 배우
# ======>3:이채은 배우
# ======>4:조복래 배우
# ======>5:장동건 배우
# ======>6:김대명 배우
# ======>7:장광 배우
# ======>1:민진웅 배우
# ======>2:허율 배우
# ======>3:이수민 배우
# ======>4:김예은 배우
# ======>5:김원해 배우
# ======>6:김도윤 배우
# ======>7:차순배 배우
# ======>1:슈가 배우
# ======>2:유수빈 배우
# ======>3:예수정 배우
# ======>4:손석구 배우
# ======>5:류덕환 배우
# ======>6:이상원 배우
# ======>7:엄상현 배우
# ======>1:정원중 배우
# ======>2:신용우 배우
# ======>3:김혜옥 배우
# ======>4:위하준 배우
# ======>5:전여빈 배우
# ======>6:최무성 배우
# ======>7:고창석 배우
# ======>1:김경덕 배우
# ======>2:김사랑 배우
# ======>3:정혜린 배우
# ======>4:김명민 배우
# ======>5:김보민 배우
# ======>6:박지현 배우
# ======>7:김민호 배우
# ======>1:조현철 배우
# ======>2:조운 배우
# ======>3:김상호 배우
# ======>4:옥자연 배우
# ======>5:신정근 배우
# ======>6:김광규 배우
# ======>7:박명훈 배우
# ======>1:김현지 배우
# ======>2:김영은 배우
# ======>3:배두나 배우
# ======>4:조이현 배우
# ======>5:박소이 배우
# ======>6:유연석 배우
# ======>7:최민호 배우
# ======>1:손현주 배우
# ======>2:제이홉 배우
# ======>3:원현준 배우
# ======>4:서예지 배우
# ======>5:윤찬영 배우
# ======>6:안길강 배우
# ======>7:시영준 배우
# ======>1:장동주 배우
# ======>2:정하담 배우
# ======>3:한수현 배우
# ======>4:남도형 배우
# ======>5:키 배우
# ======>6:김국희 배우
# ======>7:이가섭 배우
# ======>1:송재룡 배우
# ======>2:임지연 배우
# ======>3:장성범 배우
# ======>4:신혜선 배우
# ======>5:신세휘 배우
# ======>6:김강훈 배우
# ======>7:김인권 배우
# ======>1:류수영 배우
# ======>2:한지민 배우
# ======>3:지우 배우
# ======>4:사문영 배우
# ======>5:최원영 배우
# ======>6:김명곤 배우
# ======>7:김용림 배우
# ======>1:정지훈 배우
# ======>2:주우재 배우
# ======>3:강신철 배우
# ======>4:이영애 배우
# ======>5:배종옥 배우
# ======>6:손우현 배우
# ======>7:전혜빈 배우
# ======>1:김수진 배우
# ======>2:김환진 배우
# ======>3:이항나 배우
# ======>4:이선 배우
# ======>5:김서영 배우
# ======>6:정해균 배우
# ======>7:김현목 배우
# ======>1:김채하 배우
# ======>2:임원희 배우
# ======>3:백수장 배우
# ======>4:박해수 배우
# ======>5:황정민 배우
# ======>6:정유진 배우
# ======>7:지민 배우
# ======>1:송윤아 배우
# ======>2:박해일 배우
# ======>3:온주완 배우
# ======>4:남문철 배우
# ======>5:주진모 배우
# ======>6:임형준 배우
# ======>7:이미자 배우
# ======>1:안내상 배우
# ======>2:조달환 배우
# ======>3:곽시양 배우
# ======>4:김동건 배우
# ======>5:홍경 배우
# ======>6:조경이 배우
# ======>7:류한비 배우
# ======>1:심희섭 배우
# ======>2:조현영 배우
# ======>3:오광록 배우
# ======>4:조인성 배우
# ======>5:김형묵 배우
# ======>6:전미선 배우
# ======>7:류경수 배우
# ======>1:이지현 배우
# ======>2:박경혜 배우
# ======>3:김새론 배우
# ======>4:이얼 배우
# ======>5:김해곤 배우
# ======>6:천우희 배우
# ======>7:남주혁 배우
# ======>1:장지건 배우
# ======>2:이원근 배우
# ======>3:박상훈 배우
# ======>4:정가람 배우
# ======>5:이현욱 배우
# ======>6:홍소영 배우
# ======>7:태항호 배우
# ======>1:박병은 배우
# ======>2:최준영 배우
# ======>3:권소현 배우
# ======>4:강홍석 배우
# ======>5:김호중 배우
# ======>6:김수안 배우
# ======>7:박근록 배우
# ======>1:박영남 배우
# ======>2:서현우 배우
# ======>3:엄태구 배우
# ======>4:박종환 배우
# ======>5:이재용 배우
# ======>6:박진우 배우
# ======>7:김혜성 배우
# ======>1:이정은 배우
# ======>2:안소이 배우
# ======>3:이현 배우
# ======>4:이상엽 배우
# ======>5:박성훈 배우
# ======>6:정미숙 배우
# ======>7:윤여정 배우
# ======>1:이호정 배우
# ======>2:뷔 배우
# ======>3:홍기준 배우
# ======>4:유선 배우
# ======>5:강희선 배우
# ======>6:이천희 배우
# ======>7:최광일 배우
# --->50페이지 출력됨
# ======>1:박혁권 배우
# ======>2:김준한 배우
# ======>3:전석호 배우
# ======>4:송새벽 배우
# ======>5:조수향 배우
# ======>6:갈소원 배우
# ======>7:김설현 배우
# ======>1:길해연 배우
# ======>2:박동혁 배우
# ======>3:전진아 배우
# ======>4:김응수 배우
# ======>5:
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# ">
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
#  배우
# ======>6:이주영 배우
# ======>7:고규필 배우
# ======>1:정승욱 배우
# ======>2:지현준 배우
# ======>3:김시아 배우
# ======>4:이승희 배우
# ======>5:박형수 배우
# ======>6:권소현 배우
# ======>7:김서형 배우
# ======>1:정동환 배우
# ======>2:이재욱 배우
# ======>3:동하 배우
# ======>4:최재환 배우
# ======>5:권성혁 배우
# ======>6:정재헌 배우
# ======>7:이풍운 배우
# ======>1:김경희 배우
# ======>2:여민정 배우
# ======>3:문승아 배우
# ======>4:문소리 배우
# ======>5:유열 배우
# ======>6:김복동 배우
# ======>7:최한 배우
# ======>1:이서환 배우
# ======>2:오대환 배우
# ======>3:탕준상 배우
# ======>4:박성근 배우
# ======>5:홍진욱 배우
# ======>6:박지영 배우
# ======>7:김민상 배우
# ======>1:이유영 배우
# ======>2:신현빈 배우
# ======>3:이관희 배우
# ======>4:변희봉 배우
# ======>5:배해선 배우
# ======>6:조현도 배우
# ======>7:최상훈 배우
# ======>1:동방우 배우
# ======>2:신민아 배우
# ======>3:성지루 배우
# ======>4:유인나 배우
# ======>5:윤세웅 배우
# ======>6:이중옥 배우
# ======>7:김슬기 배우
# ======>1:오희준 배우
# ======>2:장혁 배우
# ======>3:박지일 배우
# ======>4:사성웅 배우
# ======>5:정혜원 배우
# ======>6:이장원 배우
# ======>7:전소니 배우
# ======>1:오동민 배우
# ======>2:임한빈 배우
# ======>3:서반석 배우
# ======>4:유호한 배우
# ======>5:차래형 배우
# ======>6:정재영 배우
# ======>7:신수연 배우
# ======>1:차엽 배우
# ======>2:오혜원 배우
# ======>3:신동미 배우
# ======>4:수영 배우
# ======>5:이선호 배우
# ======>6:김수미 배우
# ======>7:지일주 배우
# ======>1:정은채 배우
# ======>2:이순재 배우
# ======>3:임형국 배우
# ======>4:전광주 배우
# ======>5:정상훈 배우
# ======>6:이시언 배우
# ======>7:유진우 배우
# ======>1:박형식 배우
# ======>2:서정연 배우
# ======>3:김연우 배우
# ======>4:김현수 배우
# ======>5:진경 배우
# ======>6:민지아 배우
# ======>7:이범수 배우
# ======>1:소연 배우
# ======>2:준호 배우
# ======>3:서지혜 배우
# ======>4:정은지 배우
# ======>5:정인기 배우
# ======>6:김소희 배우
# ======>7:주석태 배우
# ======>1:심규혁 배우
# ======>2:정국 배우
# ======>3:추상미 배우
# ======>4:윤정일 배우
# ======>5:윤세아 배우
# ======>6:김보나 배우
# ======>7:유오성 배우
# ======>1:강보경 배우
# ======>2:이태형 배우
# ======>3:엄지원 배우
# ======>4:정소민 배우
# ======>5:김영재 배우
# ======>6:이종구 배우
# ======>7:배수빈 배우
# ======>1:정유미 배우
# ======>2:오은주 배우
# ======>3:백현진 배우
# ======>4:김미경 배우
# ======>5:임채헌 배우
# ======>6:조재윤 배우
# ======>7:이성우 배우
# ======>1:윤박 배우
# ======>2:장혁진 배우
# ======>3:이찬유 배우
# ======>4:박세진 배우
# ======>5:전태열 배우
# ======>6:김은아 배우
# ======>7:이수경 배우
# ======>1:이종혁 배우
# ======>2:강시현 배우
# ======>3:노무현 배우
# ======>4:이성열 배우
# ======>5:예지원 배우
# ======>6:손예진 배우
# ======>7:정규수 배우
# ======>1:김리흔 배우
# ======>2:유희제 배우
# ======>3:서영희 배우
# ======>4:임영웅 배우
# ======>5:김희애 배우
# ======>6:정혜옥 배우
# ======>7:서문석 배우
# ======>1:김지혜 배우
# ======>2:진선미 배우
# ======>3:이태석 배우
# ======>4:장민혁 배우
# ======>5:황창영 배우
# ======>6:한이진 배우
# ======>7:조지환 배우
# ======>1:강은애 배우
# ======>2:박예나 배우
# ======>3:이경훈 배우
# ======>4:영탁 배우
# ======>5:정유정 배우
# ======>6:신창수 배우
# ======>7:김소혜 배우
# ======>1:이나경 배우
# ======>2:차수연 배우
# ======>3:전노민 배우
# ======>4:박지윤 배우
# ======>5:박지후 배우
# ======>6:신승환 배우
# ======>7:최윤영 배우
# ======>1:배누리 배우
# ======>2:백주희 배우
# ======>3:탁원정 배우
# ======>4:이학주 배우
# ======>5:이진주 배우
# ======>6:홍범기 배우
# ======>7:이주영 배우
# ======>1:이창민 배우
# ======>2:최명빈 배우
# ======>3:금새록 배우
# ======>4:장병관 배우
# ======>5:김해숙 배우
# ======>6:홍시호 배우
# ======>7:현봉식 배우
# ======>1:이일화 배우
# ======>2:최원형 배우
# ======>3:박영진 배우
# ======>4:진유영 배우
# ======>5:박중금 배우
# ======>6:이주원 배우
# ======>7:권혁범 배우
# ======>1:이찬원 배우
# ======>2:박영재 배우
# ======>3:박호산 배우
# ======>4:민경진 배우
# ======>5:이승연 배우
# ======>6:정의한 배우
# ======>7:이창훈 배우
# ======>1:방연지 배우
# ======>2:이한서 배우
# ======>3:조영진 배우
# ======>4:김보성 배우
# ======>5:손호준 배우
# ======>6:고수희 배우
# ======>7:박성광 배우
# ======>1:심완준 배우
# ======>2:연우진 배우
# ======>3:김보라 배우
# ======>4:정애화 배우
# ======>5:김승훈 배우
# ======>6:배정화 배우
# ======>7:김영광 배우
# ======>1:현경수 배우
# ======>2:정지훈 배우
# ======>3:최다니엘 배우
# ======>4:정종준 배우
# ======>5:강예원 배우
# ======>6:김창옥 배우
# ======>7:임은정 배우
# ======>1:이소연 배우
# ======>2:윤송아 배우
# ======>3:김호정 배우
# ======>4:조승우 배우
# ======>5:윤용식 배우
# ======>6:김옥경 배우
# ======>7:왕지혜 배우
# ======>1:김기두 배우
# ======>2:손선영 배우
# ======>3:이민혁 배우
# ======>4:이문식 배우
# ======>5:문남숙 배우
# ======>6:오민석 배우
# ======>7:남보라 배우
# ======>1:전현무 배우
# ======>2:박성영 배우
# ======>3:김선혜 배우
# ======>4:신주환 배우
# ======>5:김성녀 배우
# ======>6:전숙경 배우
# ======>7:홍승효 배우
# ======>1:박수연 배우
# ======>2:정영숙 배우
# ======>3:박누가 배우
# ======>4:강승현 배우
# ======>5:박원상 배우
# ======>6:임성재 배우
# ======>7:정동원 배우
# ======>1:한지은 배우
# ======>2:민효린 배우
# ======>3:김현숙 배우
# ======>4:유아 배우
# ======>5:김현심 배우
# ======>6:김준현 배우
# ======>7:지성 배우
# ======>1:손상연 배우
# ======>2:장경희 배우
# ======>3:서홍석 배우
# ======>4:서지영 배우
# ======>5:오의식 배우
# ======>6:김수현 배우
# ======>7:김한나 배우
# ======>1:이나라 배우
# ======>2:이상호 배우
# ======>3:박준형 배우
# ======>4:서주희 배우
# ======>5:손나은 배우
# ======>6:여회현 배우
# ======>7:심은경 배우
# ======>1:배정미 배우
# ======>2:하지은 배우
# ======>3:유호정 배우
# ======>4:백윤식 배우
# ======>5:이세영 배우
# ======>6:김보영 배우
# ======>7:종호 배우
# ======>1:김나연 배우
# ======>2:최승훈 배우
# ======>3:박주미 배우
# ======>4:정준원 배우
# ======>5:이소영 배우
# ======>6:백봉기 배우
# ======>7:양동근 배우
# ======>1:박민지 배우
# ======>2:문채원 배우
# ======>3:장원영 배우
# ======>4:강석 배우
# ======>5:강성우 배우
# ======>6:한으뜸 배우
# ======>7:장민호 배우
# ======>1:전후석 배우
# ======>2:박지훈 배우
# ======>3:이유리 배우
# ======>4:유민상 배우
# ======>5:채민지 배우
# ======>6:김영민 배우
# ======>7:김소형 배우
# ======>1:이주원 배우
# ======>2:성혁 배우
# ======>3:이원종 배우
# ======>4:조연우 배우
# ======>5:최정윤 배우
# ======>6:채수빈 배우
# ======>7:김동완 배우
# ======>1:박효주 배우
# ======>2:안지호 배우
# ======>3:강말금 배우
# ======>4:신은수 배우
# ======>5:구본웅 배우
# ======>6:이현균 배우
# ======>7:안장혁 배우
# ======>1:이태리 배우
# ======>2:유이화 배우
# ======>3:장다운 배우
# ======>4:김민준 배우
# ======>5:김노진 배우
# ======>6:송하림 배우
# ======>7:송창의 배우
# ======>1:주예림 배우
# ======>2:이준혁 배우
# ======>3:태인호 배우
# ======>4:이금희 배우
# ======>5:하연수 배우
# ======>6:이상희 배우
# ======>7:방지원 배우
# ======>1:임지호 배우
# ======>2:이규성 배우
# ======>3:변영희 배우
# ======>4:정원창 배우
# ======>5:이혜리 배우
# ======>6:이동훈 배우
# ======>7:김사라 배우
# ======>1:이인석 배우
# ======>2:오현경 배우
# ======>3:성훈 배우
# ======>4:천정명 배우
# ======>5:황보라 배우
# ======>6:최정현 배우
# ======>7:손숙 배우
# ======>1:이지훈 배우
# ======>2:박금분 배우
# ======>3:신수항 배우
# ======>4:손성윤 배우
# ======>5:김민재 배우
# ======>6:손담비 배우
# ======>7:정형석 배우
# ======>1:김민주 배우
# ======>2:정재현 배우
# ======>3:장은숙 배우
# ======>4:이봉근 배우
# ======>5:전수지 배우
# ======>6:곽두조 배우
# ======>7:박광재 배우
# ======>1:조민수 배우
# ======>2:박보경 배우
# ======>3:오나미 배우
# ======>4:조진숙 배우
# ======>5:양흥주 배우
# ======>6:진이한 배우
# ======>7:허가윤 배우
# --->100페이지 출력됨
# ======>1:최덕희 배우
# ======>2:조병규 배우
# ======>3:나애진 배우
# ======>4:문보람 배우
# ======>5:이청아 배우
# ======>6:정무성 배우
# ======>7:신정훈 배우
# ======>1:류아벨 배우
# ======>2:강태오 배우
# ======>3:권은비 배우
# ======>4:강금연 배우
# ======>5:최정인 배우
# ======>6:김동욱 배우
# ======>7:오인성 배우
# ======>1:이새봄 배우
# ======>2:박준면 배우
# ======>3:송재호 배우
# ======>4:김홍표 배우
# ======>5:설혜인 배우
# ======>6:이로운 배우
# ======>7:이미도 배우
# ======>1:홍정인 배우
# ======>2:강혜원 배우
# ======>3:김규리 배우
# ======>4:김호창 배우
# ======>5:홍종현 배우
# ======>6:김학선 배우
# ======>7:박리나 배우
# ======>1:연지원 배우
# ======>2:김다올 배우
# ======>3:이시아 배우
# ======>4:안현서 배우
# ======>5:고구인 배우
# ======>6:박현영 배우
# ======>7:고성희 배우
# ======>1:기주봉 배우
# ======>2:김나니 배우
# ======>3:김희재 배우
# ======>4:임예진 배우
# ======>5:이하율 배우
# ======>6:오지호 배우
# ======>7:안윤선 배우
# ======>1:노강민 배우
# ======>2:이다슬 배우
# ======>3:박용우 배우
# ======>4:최예나 배우
# ======>5:이호산 배우
# ======>6:서영화 배우
# ======>7:구성환 배우
# ======>1:한만중 배우
# ======>2:박자희 배우
# ======>3:문동환 배우
# ======>4:홍수아 배우
# ======>5:박충선 배우
# ======>6:김민희 배우
# ======>7:김서연 배우
# ======>1:윤복인 배우
# ======>2:한철우 배우
# ======>3:정두홍 배우
# ======>4:유시민 배우
# ======>5:임성철 배우
# ======>6:김일우 배우
# ======>7:최로운 배우
# ======>1:최은희 배우
# ======>2:김병춘 배우
# ======>3:이명희 배우
# ======>4:양윤희 배우
# ======>5:오지혜 배우
# ======>6:김순규 배우
# ======>7:김현수 배우
# ======>1:치타 배우
# ======>2:이채연 배우
# ======>3:이열음 배우
# ======>4:한송희 배우
# ======>5:류의도 배우
# ======>6:박월선 배우
# ======>7:김정훈 배우
# ======>1:안영미 배우
# ======>2:김보윤 배우
# ======>3:지창욱 배우
# ======>4:김무늬 배우
# ======>5:이경태 배우
# ======>6:김채원 배우
# ======>7:김진규 배우
# ======>1:박지빈 배우
# ======>2:곽진석 배우
# ======>3:김소은 배우
# ======>4:최정운 배우
# ======>5:곽희성 배우
# ======>6:김우진 배우
# ======>7:최정윤 배우
# ======>1:이봄 배우
# ======>2:최고 배우
# ======>3:신영균 배우
# ======>4:정이랑 배우
# ======>5:김소현 배우
# ======>6:이재구 배우
# ======>7:임세주 배우
# ======>1:다현 배우
# ======>2:권오중 배우
# ======>3:윤아영 배우
# ======>4:양동남 배우
# ======>5:조은지 배우
# ======>6:정은경 배우
# ======>7:민형식 배우
# ======>1:윤승아 배우
# ======>2:곽동연 배우
# ======>3:혁 배우
# ======>4:김두선 배우
# ======>5:박지현 배우
# ======>6:문성근 배우
# ======>7:안효민 배우
# ======>1:김대중 배우
# ======>2:최희서 배우
# ======>3:문영동 배우
# ======>4:이지예 배우
# ======>5:미나 배우
# ======>6:김꽃비 배우
# ======>7:배상우 배우
# ======>1:장세아 배우
# ======>2:이한위 배우
# ======>3:김진영 배우
# ======>4:송영인 배우
# ======>5:이상헌 배우
# ======>6:김유림 배우
# ======>7:허성재 배우
# ======>1:이창성 배우
# ======>2:송선미 배우
# ======>3:조유리 배우
# ======>4:이명호 배우
# ======>5:이규복 배우
# ======>6:김아송 배우
# ======>7:황석정 배우
# ======>1:백서빈 배우
# ======>2:심환 배우
# ======>3:정재광 배우
# ======>4:이성혜 배우
# ======>5:보라 배우
# ======>6:성병숙 배우
# ======>7:박상훈 배우
# ======>1:문창길 배우
# ======>2:김하연 배우
# ======>3:임수정 배우
# ======>4:김지희 배우
# ======>5:차종수 배우
# ======>6:김려원 배우
# ======>7:유승호 배우
# ======>1:박승준 배우
# ======>2:김승호 배우
# ======>3:이원순 배우
# ======>4:안유진 배우
# ======>5:손지현 배우
# ======>6:차지혁 배우
# ======>7:손수아 배우
# ======>1:김성연 배우
# ======>2:이시우 배우
# ======>3:서은아 배우
# ======>4:홍수정 배우
# ======>5:김새해 배우
# ======>6:오현중 배우
# ======>7:허지연 배우
# ======>1:이운숙 배우
# ======>2:권영찬 배우
# ======>3:홍지석 배우
# ======>4:안지혜 배우
# ======>5:이린하 배우
# ======>6:오기철 배우
# ======>7:이용규 배우
# ======>1:손정아 배우
# ======>2:조선기 배우
# ======>3:한인수 배우
# ======>4:김상경 배우
# ======>5:장원영 배우
# ======>6:박선영 배우
# ======>7:김을분 배우
# ======>1:김희진 배우
# ======>2:김소민 배우
# ======>3:정희태 배우
# ======>4:오하늬 배우
# ======>5:채지희 배우
# ======>6:유진 배우
# ======>7:이고은 배우
# ======>1:박예영 배우
# ======>2:장하은 배우
# ======>3:김희상 배우
# ======>4:주해은 배우
# ======>5:김강현 배우
# ======>6:서원석 배우
# ======>7:박건주 배우
# ======>1:김주아 배우
# ======>2:강희 배우
# ======>3:이강갑 배우
# ======>4:한수연 배우
# ======>5:김건호 배우
# ======>6:황현주 배우
# ======>7:옥윤중 배우
# ======>1:김준경 배우
# ======>2:박복형 배우
# ======>3:강신성일 배우
# ======>4:최정원 배우
# ======>5:전채은 배우
# ======>6:심용환 배우
# ======>7:이엘리야 배우
# ======>1:곽민규 배우
# ======>2:김소희 배우
# ======>3:김중희 배우
# ======>4:서다혜 배우
# ======>5:영민 배우
# ======>6:문선희 배우
# ======>7:삼숙 배우
# ======>1:나민희 배우
# ======>2:박수민 배우
# ======>3:김준범 배우
# ======>4:동효희 배우
# ======>5:남궁원 배우
# ======>6:허지나 배우
# ======>7:정다은 배우
# ======>1:김광식 배우
# ======>2:홍주성 배우
# ======>3:이어령 배우
# ======>4:도금봉 배우
# ======>5:임시완 배우
# ======>6:정제원 배우
# ======>7:최낙윤 배우
# ======>1:홍완표 배우
# ======>2:이제훈 배우
# ======>3:백재민 배우
# ======>4:윤혜리 배우
# ======>5:여준환 배우
# ======>6:장동윤 배우
# ======>7:조예신 배우
# ======>1:이민하 배우
# ======>2:박초롱 배우
# ======>3:지만원 배우
# ======>4:이순도 배우
# ======>5:소정환 배우
# ======>6:라경덕 배우
# ======>7:이소은 배우
# ======>1:김상동 배우
# ======>2:김중기 배우
# ======>3:김자연 배우
# ======>4:김혜성 배우
# ======>5:오창경 배우
# ======>6:윤성모 배우
# ======>7:허정도 배우
# ======>1:신한호 배우
# ======>2:민무제 배우
# ======>3:서영재 배우
# ======>4:권창욱 배우
# ======>5:한해인 배우
# ======>6:김도훈 배우
# ======>7:조현식 배우
# ======>1:정의갑 배우
# ======>2:한은진 배우
# ======>3:한경화 배우
# ======>4:조서연 배우
# ======>5:민병우 배우
# ======>6:김민주 배우
# ======>7:오지헌 배우
# ======>1:신신애 배우
# ======>2:김희갑 배우
# ======>3:허장강 배우
# ======>4:조슬아 배우
# ======>5:이대근 배우
# ======>6:이옥선 배우
# ======>7:김태리 배우
# ======>1:이기우 배우
# ======>2:김승현 배우
# ======>3:이봉준 배우
# ======>4:도지한 배우
# ======>5:김영애 배우
# ======>6:정영웅 배우
# ======>7:김대한 배우
# ======>1:김기천 배우
# ======>2:이자옥 배우
# ======>3:윤진서 배우
# ======>4:안지환 배우
# ======>5:우상전 배우
# ======>6:민승연 배우
# ======>7:이용수 배우
# ======>1:민경훈 배우
# ======>2:서벽준 배우
# ======>3:오승훈 배우
# ======>4:류성현 배우
# ======>5:김지미 배우
# ======>6:허정민 배우
# ======>7:김정현 배우
# ======>1:신민재 배우
# ======>2:이지연 배우
# ======>3:이도하 배우
# ======>4:강수진 배우
# ======>5:김명국 배우
# ======>6:김준배 배우
# ======>7:장리우 배우
# ======>1:고서희 배우
# ======>2:안보현 배우
# ======>3:박선영 배우
# ======>4:한상혁 배우
# ======>5:서나영 배우
# ======>6:하희라 배우
# ======>7:김주령 배우
# ======>1:김순덕 배우
# ======>2:고동업 배우
# ======>3:우미화 배우
# ======>4:이주은 배우
# ======>5:정예진 배우
# ======>6:주석희 배우
# ======>7:김하늘 배우
# ======>1:엄앵란 배우
# ======>2:김승준 배우
# ======>3:홍근택 배우
# ======>4:송지인 배우
# ======>5:김뢰하 배우
# ======>6:문정숙 배우
# ======>7:백종학 배우
# ======>1:나혜미 배우
# ======>2:이선희 배우
# ======>3:고관재 배우
# ======>4:허예은 배우
# ======>5:김병옥 배우
# ======>6:박노식 배우
# ======>7:강진아 배우
# ======>1:박선영 배우
# ======>2:박혜나 배우
# ======>3:주증녀 배우
# ======>4:조용주 배우
# ======>5:남유정 배우
# ======>6:이인성 배우
# ======>7:서태화 배우
# ======>1:황정순 배우
# ======>2:김영선 배우
# ======>3:김동영 배우
# ======>4:김민주 배우
# ======>5:곽진무 배우
# ======>6:김동원 배우
# ======>7:김현욱 배우
# ======>1:문희 배우
# ======>2:유다인 배우
# ======>3:유다미 배우
# ======>4:정상윤 배우
# ======>5:김재욱 배우
# ======>6:신석호 배우
# ======>7:이비안 배우
# ======>1:강길우 배우
# ======>2:최무룡 배우
# ======>3:김윤식 배우
# ======>4:남규리 배우
# ======>5:김조연 배우
# ======>6:김상원 배우
# ======>7:정주원 배우
# --->150페이지 출력됨
# ======>1:김다예 배우
# ======>2:김민주 배우
# ======>3:신소율 배우
# ======>4:김군자 배우
# ======>5:곽규미 배우
# ======>6:황유림 배우
# ======>7:강구한 배우
# ======>1:천정은 배우
# ======>2:홍석연 배우
# ======>3:최수인 배우
# ======>4:윤승욱 배우
# ======>5:심은하 배우
# ======>6:이정현 배우
# ======>7:김도영 배우
# ======>1:이재원 배우
# ======>2:고원희 배우
# ======>3:류현경 배우
# ======>4:조미령 배우
# ======>5:이상각 배우
# ======>6:박노식 배우
# ======>7:동현배 배우
# ======>1:김정영 배우
# ======>2:차지현 배우
# ======>3:박상증 배우
# ======>4:조한선 배우
# ======>5:정영주 배우
# ======>6:
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# ">
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
#  배우
# ======>7:이해준 배우
# ======>1:김여진 배우
# ======>2:이원찬 배우
# ======>3:장재희 배우
# ======>4:조수원 배우
# ======>5:박요한 배우
# ======>6:남기애 배우
# ======>7:유준상 배우
# ======>1:마민지 배우
# ======>2:김희철 배우
# ======>3:설영범 배우
# ======>4:윤일봉 배우
# ======>5:강일출 배우
# ======>6:지대한 배우
# ======>7:박재한 배우
# ======>1:윤금선아 배우
# ======>2:이승찬 배우
# ======>3:임화영 배우
# ======>4:김아현 배우
# ======>5:차지현 배우
# ======>6:송준석 배우
# ======>7:마흥식 배우
# ======>1:강민준 배우
# ======>2:정지혜 배우
# ======>3:김수진 배우
# ======>4:이미나 배우
# ======>5:여균동 배우
# ======>6:변중희 배우
# ======>7:오달수 배우
# ======>1:이연 배우
# ======>2:선우일란 배우
# ======>3:채경선 배우
# ======>4:우지현 배우
# ======>5:선우선 배우
# ======>6:윤정희 배우
# ======>7:하하 배우
# ======>1:이상원 배우
# ======>2:임희철 배우
# ======>3:정유연 배우
# ======>4:신재훈 배우
# ======>5:김금순 배우
# ======>6:송재림 배우
# ======>7:진구 배우
# ======>1:김지훈 배우
# ======>2:권한솔 배우
# ======>3:엄경환 배우
# ======>4:이상범 배우
# ======>5:남연우 배우
# ======>6:민지현 배우
# ======>7:이은심 배우
# ======>1:박암 배우
# ======>2:김수정 배우
# ======>3:김정팔 배우
# ======>4:정하진 배우
# ======>5:최남현 배우
# ======>6:한기윤 배우
# ======>7:탁우석 배우
# ======>1:노수산나 배우
# ======>2:장준현 배우
# ======>3:박옥선 배우
# ======>4:임은경 배우
# ======>5:박용수 배우
# ======>6:이새아 배우
# ======>7:고태영 배우
# ======>1:장동휘 배우
# ======>2:지성원 배우
# ======>3:노정의 배우
# ======>4:이건우 배우
# ======>5:천이슬 배우
# ======>6:고윤 배우
# ======>7:진선미 배우
# ======>1:한동규 배우
# ======>2:장선 배우
# ======>3:최기섭 배우
# ======>4:이재범 배우
# ======>5:이도아 배우
# ======>6:서지희 배우
# ======>7:이대엽 배우
# ======>1:김혜나 배우
# ======>2:박보영 배우
# ======>3:정지순 배우
# ======>4:백승헌 배우
# ======>5:양현태 배우
# ======>6:최일화 배우
# ======>7:윤지혜 배우
# ======>1:김동균 배우
# ======>2:장예나 배우
# ======>3:강두 배우
# ======>4:수애 배우
# ======>5:최우제 배우
# ======>6:윤인자 배우
# ======>7:김유라 배우
# ======>1:홍승이 배우
# ======>2:남지우 배우
# ======>3:김태훈 배우
# ======>4:김혜자 배우
# ======>5:정혜성 배우
# ======>6:안홍진 배우
# ======>7:손이용 배우
# ======>1:박중훈 배우
# ======>2:신린아 배우
# ======>3:김범진 배우
# ======>4:강능원 배우
# ======>5:양소민 배우
# ======>6:이민자 배우
# ======>7:장미 배우
# ======>1:홍서백 배우
# ======>2:문희경 배우
# ======>3:김현 배우
# ======>4:이설구 배우
# ======>5:임권택 배우
# ======>6:최미경 배우
# ======>7:김막동 배우
# ======>1:신철진 배우
# ======>2:김시은 배우
# ======>3:지돌이 배우
# ======>4:황해 배우
# ======>5:최원용 배우
# ======>6:하박 배우
# ======>7:이용녀 배우
# ======>1:류승완 배우
# ======>2:이용한 배우
# ======>3:이진욱 배우
# ======>4:류태호 배우
# ======>5:형영선 배우
# ======>6:문지인 배우
# ======>7:진기주 배우
# ======>1:민지혁 배우
# ======>2:정다원 배우
# ======>3:하주희 배우
# ======>4:이효제 배우
# ======>5:박지아 배우
# ======>6:오창석 배우
# ======>7:권태원 배우
# ======>1:이영석 배우
# ======>2:김라희 배우
# ======>3:김태희 배우
# ======>4:이화시 배우
# ======>5:하휘동 배우
# ======>6:문숙 배우
# ======>7:남정임 배우
# ======>1:한신 배우
# ======>2:이서연 배우
# ======>3:최홍일 배우
# ======>4:김대건 배우
# ======>5:조선묵 배우
# ======>6:유상재 배우
# ======>7:원빈 배우
# ======>1:원빈 배우
# ======>2:김점순 배우
# ======>3:이주실 배우
# ======>4:이나영 배우
# ======>5:이진이 배우
# ======>6:유순웅 배우
# ======>7:박지나 배우
# ======>1:김희라 배우
# ======>2:임정환 배우
# ======>3:정형석 배우
# ======>4:이경준 배우
# ======>5:김다희 배우
# ======>6:이미형 배우
# ======>7:김석훈 배우
# ======>1:구봉서 배우
# ======>2:김성옥 배우
# ======>3:황윤 배우
# ======>4:하준 배우
# ======>5:유영국 배우
# ======>6:서갑숙 배우
# ======>7:서우 배우
# ======>1:남석훈 배우
# ======>2:기호 배우
# ======>3:천호진 배우
# ======>4:남일우 배우
# ======>5:문지윤 배우
# ======>6:이현웅 배우
# ======>7:맹세창 배우
# ======>1:박점례 배우
# ======>2:백승환 배우
# ======>3:유태균 배우
# ======>4:감승민 배우
# ======>5:정가영 배우
# ======>6:김광석 배우
# ======>7:구윤영 배우
# ======>1:구윤영 배우
# ======>2:한효주 배우
# ======>3:최유하 배우
# ======>4:전신환 배우
# ======>5:심형탁 배우
# ======>6:강하늘 배우
# ======>7:정수지 배우
# ======>1:최명길 배우
# ======>2:테오 배우
# ======>3:독고성 배우
# ======>4:권혜원 배우
# ======>5:이룡 배우
# ======>6:이예춘 배우
# ======>7:김윤지 배우
# ======>1:김옥빈 배우
# ======>2:고소영 배우
# ======>3:김영호 배우
# ======>4:최삼 배우
# ======>5:최병모 배우
# ======>6:최남미 배우
# ======>7:옥수분 배우
# ======>1:이태경 배우
# ======>2:장인섭 배우
# ======>3:김재록 배우
# ======>4:김미라 배우
# ======>5:서도현 배우
# ======>6:우정국 배우
# ======>7:이상보 배우
# ======>1:이은주 배우
# ======>2:한태의 배우
# ======>3:박정자 배우
# ======>4:박옥련 배우
# ======>5:전고운 배우
# ======>6:지웅 배우
# ======>7:박지홍 배우
# ======>1:강애심 배우
# ======>2:김경룡 배우
# ======>3:박세준 배우
# ======>4:안소영 배우
# ======>5:김부선 배우
# ======>6:한정수 배우
# ======>7:이정길 배우
# ======>1:이재응 배우
# ======>2:황성균 배우
# ======>3:강인성 배우
# ======>4:이용훈 배우
# ======>5:김사희 배우
# ======>6:김주영 배우
# ======>7:장미희 배우
# ======>1:강은탁 배우
# ======>2:안기임 배우
# ======>3:백종승 배우
# ======>4:전소민 배우
# ======>5:손민지 배우
# ======>6:이세랑 배우
# ======>7:박세민 배우
# ======>1:유하 배우
# ======>2:김동우 배우
# ======>3:임창정 배우
# ======>4:김욱 배우
# ======>5:김유연 배우
# ======>6:이형석 배우
# ======>7:최은진 배우
# ======>1:인탁 배우
# ======>2:최보윤 배우
# ======>3:정찬 배우
# ======>4:박인수 배우
# ======>5:박수영 배우
# ======>6:김하림 배우
# ======>7:김도영 배우
# ======>1:이철민 배우
# ======>2:유혜리 배우
# ======>3:이엘 배우
# ======>4:김성은 배우
# ======>5:조민경 배우
# ======>6:최윤석 배우
# ======>7:이광자 배우
# ======>1:이상호 배우
# ======>2:더 콰이엇 배우
# ======>3:강은우 배우
# ======>4:강선숙 배우
# ======>5:김록경 배우
# ======>6:남상일 배우
# ======>7:이광현 배우
# ======>1:박성빈 배우
# ======>2:감소현 배우
# ======>3:송유현 배우
# ======>4:황선 배우
# ======>5:송유담 배우
# ======>6:김가영 배우
# ======>7:종섭 배우
# ======>1:최종원 배우
# ======>2:박근수 배우
# ======>3:정혁기 배우
# ======>4:최정원 배우
# ======>5:윤봉길 배우
# ======>6:정영기 배우
# ======>7:여현수 배우
# ======>1:신문성 배우
# ======>2:김신재 배우
# ======>3:이시후 배우
# ======>4:최성호 배우
# ======>5:김인문 배우
# ======>6:최현아 배우
# ======>7:구자형 배우
# ======>1:이인옥 배우
# ======>2:윤금순 배우
# ======>3:유지영 배우
# ======>4:김해나 배우
# ======>5:김희연 배우
# ======>6:최진영 배우
# ======>7:박경순 배우
# ======>1:박상면 배우
# ======>2:윤기형 배우
# ======>3:한상덕 배우
# ======>4:딥플로우 배우
# ======>5:조은빛 배우
# ======>6:김가희 배우
# ======>7:안인숙 배우
# ======>1:임현성 배우
# ======>2:신윤주 배우
# ======>3:김규선 배우
# ======>4:맹봉학 배우
# ======>5:김고은 배우
# ======>6:김진근 배우
# ======>7:황태광 배우
# ======>1:곽규석 배우
# ======>2:우고나 배우
# ======>3:서은수 배우
# ======>4:김창숙 배우
# ======>5:이민 배우
# ======>6:임동진 배우
# ======>7:박상규 배우
# ======>1:임동진 배우
# ======>2:박상규 배우
# ======>3:여무영 배우
# ======>4:방희 배우
# ======>5:이도경 배우
# ======>6:오아연 배우
# ======>7:한사명 배우
# --->200페이지 출력됨
# ======>1:강한샘 배우
# ======>2:문종원 배우
# ======>3:최승호 배우
# ======>4:권미아 배우
# ======>5:이승연 배우
# ======>6:이대연 배우
# ======>7:최여진 배우
# ======>1:최주봉 배우
# ======>2:이승연 배우
# ======>3:이유진 배우
# ======>4:조병만 배우
# ======>5:김경재 배우
# ======>6:양조아 배우
# ======>7:정용화 배우
# ======>1:김정균 배우
# ======>2:양조아 배우
# ======>3:김갑수 배우
# ======>4:강신효 배우
# ======>5:MC 메타 배우
# ======>6:박민상 배우
# ======>7:조안 배우
# ======>1:조준희 배우
# ======>2:이영옥 배우
# ======>3:최태환 배우
# ======>4:박아인 배우
# ======>5:박세완 배우
# ======>6:박해빛나 배우
# ======>7:김정림 배우
# ======>1:여운계 배우
# ======>2:양훈 배우
# ======>3:황건 배우
# ======>4:이종혁 배우
# ======>5:원태희 배우
# ======>6:김예림 배우
# ======>7:한예리 배우
# ======>1:김윤진 배우
# ======>2:이재균 배우
# ======>3:최리 배우
# ======>4:차유경 배우
# ======>5:홍희용 배우
# ======>6:배중식 배우
# ======>7:조명연 배우
# ======>1:김자옥 배우
# ======>2:정연주 배우
# ======>3:이예성 배우
# ======>4:김동주 배우
# ======>5:양양금 배우
# ======>6:구윤주 배우
# ======>7:김진우 배우
# ======>1:김성희 배우
# ======>2:안예인 배우
# ======>3:이새별 배우
# ======>4:이자람 배우
# ======>5:성소민 배우
# ======>6:윤소미 배우
# ======>7:함진성 배우
# ======>1:이재인 배우
# ======>2:오지영 배우
# ======>3:박신양 배우
# ======>4:곽자형 배우
# ======>5:강경준 배우
# ======>6:김희창 배우
# ======>7:유형준 배우
# ======>1:유형준 배우
# ======>2:나라 배우
# ======>3:이승호 배우
# ======>4:홍근진 배우
# ======>5:한재이 배우
# ======>6:황금희 배우
# ======>7:박민하 배우
# ======>1:황금희 배우
# ======>2:이석형 배우
# ======>3:안세호 배우
# ======>4:산이 배우
# ======>5:이유준 배우
# ======>6:김태정 배우
# ======>7:박종철 배우
# ======>1:김복자 배우
# ======>2:김미향 배우
# ======>3:장서화 배우
# ======>4:강래연 배우
# ======>5:김주혁 배우
# ======>6:김정호 배우
# ======>7:김사권 배우
# ======>1:문미봉 배우
# ======>2:조혜정 배우
# ======>3:안서현 배우
# ======>4:유재상 배우
# ======>5:한흥만 배우
# ======>6:권율 배우
# ======>7:김혜정 배우
# ======>1:권율 배우
# ======>2:성완경 배우
# ======>3:이요섭 배우
# ======>4:김용삼 배우
# ======>5:황화순 배우
# ======>6:박정학 배우
# ======>7:김혜지 배우
# ======>1:김혜지 배우
# ======>2:연제욱 배우
# ======>3:백학기 배우
# ======>4:신예주 배우
# ======>5:김예나 배우
# ======>6:이보영 배우
# ======>7:박진수 배우
# ======>1:전혜영 배우
# ======>2:한주영 배우
# ======>3:이건우 배우
# ======>4:황정아 배우
# ======>5:김상현 배우
# ======>6:한복현 배우
# ======>7:전수경 배우
# ======>1:전수경 배우
# ======>2:한보배 배우
# ======>3:안우연 배우
# ======>4:이채담 배우
# ======>5:선우용녀 배우
# ======>6:박선우 배우
# ======>7:서호철 배우
# ======>1:임지은 배우
# ======>2:이옥주 배우
# ======>3:김수연 배우
# ======>4:전지현 배우
# ======>5:이규정 배우
# ======>6:신일룡 배우
# ======>7:양택조 배우
# ======>1:춘자 배우
# ======>2:안민영 배우
# ======>3:김재화 배우
# ======>4:전계현 배우
# ======>5:이유미 배우
# ======>6:우돈기 배우
# ======>7:김윤지 배우
# ======>1:정준하 배우
# ======>2:김기춘 배우
# ======>3:나잠 수 배우
# ======>4:이현행 배우
# ======>5:소희정 배우
# ======>6:주선태 배우
# ======>7:이연두 배우
# ======>1:류성록 배우
# ======>2:스윙스 배우
# ======>3:김기형 배우
# ======>4:이설 배우
# ======>5:최지희 배우
# ======>6:박성우 배우
# ======>7:양은용 배우
# ======>1:최지희 배우
# ======>2:손병호 배우
# ======>3:송희준 배우
# ======>4:최석필 배우
# ======>5:김동석 배우
# ======>6:문희라 배우
# ======>7:이승현 배우
# ======>1:채재일 배우
# ======>2:송금식 배우
# ======>3:강혜정 배우
# ======>4:홍수현 배우
# ======>5:김애경 배우
# ======>6:고은아 배우
# ======>7:문용일 배우
# ======>1:문용일 배우
# ======>2:김익태 배우
# ======>3:이용신 배우
# ======>4:이주일 배우
# ======>5:하명중 배우
# ======>6:김시후 배우
# ======>7:최영자 배우
# ======>1:방수일 배우
# ======>2:이헌주 배우
# ======>3:진세연 배우
# ======>4:최규환 배우
# ======>5:임선우 배우
# ======>6:
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# ">
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
#  배우
# ======>7:황성준 배우
# ======>1:황성준 배우
# ======>2:전창근 배우
# ======>3:정윤희 배우
# ======>4:박하영 배우
# ======>5:이승신 배우
# ======>6:김간지 배우
# ======>7:윤아영 배우
# ======>1:윤아영 배우
# ======>2:정이서 배우
# ======>3:강석우 배우
# ======>4:강계식 배우
# ======>5:최태환 배우
# ======>6:김형범 배우
# ======>7:김정아 배우
# ======>1:한지일 배우
# ======>2:한신정 배우
# ======>3:박세은 배우
# ======>4:금보라 배우
# ======>5:전은구 배우
# ======>6:안소희 배우
# ======>7:이주예 배우
# ======>1:고인배 배우
# ======>2:유용우 배우
# ======>3:문예원 배우
# ======>4:한태일 배우
# ======>5:김종원 배우
# ======>6:변요한 배우
# ======>7:김강우 배우
# ======>1:주남정 배우
# ======>2:강계열 배우
# ======>3:김일웅 배우
# ======>4:김형민 배우
# ======>5:최영우 배우
# ======>6:임철 배우
# ======>7:서윤선 배우
# ======>1:제리 케이 배우
# ======>2:윤병희 배우
# ======>3:서윤선 배우
# ======>4:이정수 배우
# ======>5:정상현 배우
# ======>6:강민아 배우
# ======>7:김기범 배우
# ======>1:오태경 배우
# ======>2:임현식 배우
# ======>3:김단율 배우
# ======>4:박지연 배우
# ======>5:트위스트 김 배우
# ======>6:최진욱 배우
# ======>7:오수미 배우
# ======>1:최은비 배우
# ======>2:소향 배우
# ======>3:국희 배우
# ======>4:이덕화 배우
# ======>5:주소정 배우
# ======>6:양희우 배우
# ======>7:공경은 배우
# ======>1:정애란 배우
# ======>2:김희찬 배우
# ======>3:이종철 배우
# ======>4:백승철 배우
# ======>5:강봉성 배우
# ======>6:이준영 배우
# ======>7:노경희 배우
# ======>1:강봉성 배우
# ======>2:최현 배우
# ======>3:지영경 배우
# ======>4:감우성 배우
# ======>5:황현빈 배우
# ======>6:김호원 배우
# ======>7:고봉수 배우
# ======>1:고봉수 배우
# ======>2:서승원 배우
# ======>3:유정호 배우
# ======>4:임수경 배우
# ======>5:하준호 배우
# ======>6:이웅빈 배우
# ======>7:박명신 배우
# ======>1:고성진 배우
# ======>2:양익준 배우
# ======>3:김선아 배우
# ======>4:이민영 배우
# ======>5:박삼순 배우
# ======>6:김승비 배우
# ======>7:송용태 배우
# ======>1:사현진 배우
# ======>2:이경진 배우
# ======>3:윤덕용 배우
# ======>4:길원옥 배우
# ======>5:문가영 배우
# ======>6:백인호 배우
# ======>7:김정철 배우
# ======>1:최진호 배우
# ======>2:백일섭 배우
# ======>3:곽인준 배우
# ======>4:송경철 배우
# ======>5:서현철 배우
# ======>6:신일용 배우
# ======>7:남명렬 배우
# ======>1:남명렬 배우
# ======>2:민동호 배우
# ======>3:김정기 배우
# ======>4:임호준 배우
# ======>5:노지유 배우
# ======>6:최원정 배우
# ======>7:고건한 배우
# ======>1:전무송 배우
# ======>2:차지훈 배우
# ======>3:김명건 배우
# ======>4:이현주 배우
# ======>5:서월영 배우
# ======>6:류승수 배우
# ======>7:백도빈 배우
# ======>1:이재웅 배우
# ======>2:기영도 배우
# ======>3:정인선 배우
# ======>4:원준 배우
# ======>5:김슬기 배우
# ======>6:김경익 배우
# ======>7:서영주 배우
# ======>1:강성연 배우
# ======>2:배제기 배우
# ======>3:
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# ">
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
#  배우
# ======>4:김선경 배우
# ======>5:이영욱 배우
# ======>6:정우식 배우
# ======>7:정석용 배우
# ======>1:김결 배우
# ======>2:김성령 배우
# ======>3:이제연 배우
# ======>4:백소명 배우
# ======>5:한경직 배우
# ======>6:노율 배우
# ======>7:원세훈 배우
# ======>1:신원호 배우
# ======>2:장성호 배우
# ======>3:김정학 배우
# ======>4:이영숙 배우
# ======>5:홍기 배우
# ======>6:박기태 배우
# ======>7:이영아 배우
# ======>1:민채은 배우
# ======>2:차태현 배우
# ======>3:김아림 배우
# ======>4:기국서 배우
# ======>5:박미성 배우
# ======>6:복혜숙 배우
# ======>7:차룡 배우
# ======>1:한문정 배우
# ======>2:차룡 배우
# ======>3:석금성 배우
# ======>4:최영열 배우
# ======>5:이성재 배우
# ======>6:황선화 배우
# ======>7:박상준 배우
# ======>1:옥지영 배우
# ======>2:선정엽 배우
# ======>3:김광현 배우
# ======>4:양미희 배우
# ======>5:유계선 배우
# ======>6:오윤아 배우
# ======>7:박상준 배우
# ======>1:유계선 배우
# ======>2:허규 배우
# ======>3:현성 배우
# ======>4:찬열 배우
# ======>5:이춘연 배우
# ======>6:양홍석 배우
# ======>7:김용준 배우
# ======>1:찬열 배우
# ======>2:이영호 배우
# ======>3:김유정 배우
# ======>4:서정 배우
# ======>5:백지훈 배우
# ======>6:조시내 배우
# ======>7:김창은 배우
# --->250페이지 출력됨
# ======>1:김선자 배우
# ======>2:주종혁 배우
# ======>3:원미경 배우
# ======>4:김미화 배우
# ======>5:박고운 배우
# ======>6:전영운 배우
# ======>7:수아 배우
# ======>1:박고운 배우
# ======>2:렌 배우
# ======>3:추현엽 배우
# ======>4:유재석 배우
# ======>5:문석범 배우
# ======>6:고준 배우
# ======>7:최원균 배우
# ======>1:고준 배우
# ======>2:최원균 배우
# ======>3:이소현 배우
# ======>4:김단미 배우
# ======>5:김정태 배우
# ======>6:송명진 배우
# ======>7:전지학 배우
# ======>1:송미림 배우
# ======>2:김서하 배우
# ======>3:진태철 배우
# ======>4:오지은 배우
# ======>5:장상기 배우
# ======>6:이장욱 배우
# ======>7:엄태웅 배우
# ======>1:강승완 배우
# ======>2:정겨운 배우
# ======>3:남포동 배우
# ======>4:천성훈 배우
# ======>5:유용 배우
# ======>6:김주미 배우
# ======>7:공자관 배우
# ======>1:김도완 배우
# ======>2:김준면 배우
# ======>3:박채익 배우
# ======>4:변준석 배우
# ======>5:박로사 배우
# ======>6:박상용 배우
# ======>7:이해운 배우
# ======>1:김정훈 배우
# ======>2:송승헌 배우
# ======>3:변준석 배우
# ======>4:박로사 배우
# ======>5:조덕현 배우
# ======>6:이민기 배우
# ======>7:함수정 배우
# ======>1:이민기 배우
# ======>2:함수정 배우
# ======>3:유연수 배우
# ======>4:황민현 배우
# ======>5:이준익 배우
# ======>6:이칸희 배우
# ======>7:강유진 배우
# ======>1:진지희 배우
# ======>2:이혜영 배우
# ======>3:한가인 배우
# ======>4:조하영 배우
# ======>5:소비아 배우
# ======>6:권영문 배우
# ======>7:하연주 배우
# ======>1:권영문 배우
# ======>2:하연주 배우
# ======>3:채국희 배우
# ======>4:여진구 배우
# ======>5:최성관 배우
# ======>6:이수경 배우
# ======>7:김희정 배우
# ======>1:홍상표 배우
# ======>2:추봉 배우
# ======>3:권예영 배우
# ======>4:임채리 배우
# ======>5:성령 배우
# ======>6:김창환 배우
# ======>7:김환희 배우
# ======>1:성령 배우
# ======>2:김창환 배우
# ======>3:김환희 배우
# ======>4:이강조 배우
# ======>5:정현호 배우
# ======>6:장동직 배우
# ======>7:오순택 배우
# ======>1:오순택 배우
# ======>2:이윤희 배우
# ======>3:김미영 배우
# ======>4:김정난 배우
# ======>5:유지연 배우
# ======>6:박희본 배우
# ======>7:윤유선 배우
# ======>1:홍인 배우
# ======>2:김미영 배우
# ======>3:김정난 배우
# ======>4:김상순 배우
# ======>5:정휘 배우
# ======>6:김종현 배우
# ======>7:오민정 배우
# ======>1:정한비 배우
# ======>2:김진순 배우
# ======>3:김승수 배우
# ======>4:한유정 배우
# ======>5:채연 배우
# ======>6:유장현 배우
# ======>7:이승훈 배우
# ======>1:채연 배우
# ======>2:이지희 배우
# ======>3:이삼순 배우
# ======>4:강문 배우
# ======>5:김진화 배우
# ======>6:김도희 배우
# ======>7:주민하 배우
# ======>1:김도현 배우
# ======>2:양정원 배우
# ======>3:강현중 배우
# ======>4:김율 배우
# ======>5:김운하 배우
# ======>6:윤지혜 배우
# ======>7:최준우 배우
# ======>1:최일 배우
# ======>2:윤지혜 배우
# ======>3:최준우 배우
# ======>4:김현빈 배우
# ======>5:배수천 배우
# ======>6:조재성 배우
# ======>7:윤다경 배우
# ======>1:이윤회 배우
# ======>2:임예리 배우
# ======>3:김종태 배우
# ======>4:최원 배우
# ======>5:성현아 배우
# ======>6:이주현 배우
# ======>7:천보근 배우
# ======>1:최원 배우
# ======>2:성현아 배우
# ======>3:김규리 배우
# ======>4:이미숙 배우
# ======>5:황미선 배우
# ======>6:김영현 배우
# ======>7:박용팔 배우
# ======>1:박시완 배우
# ======>2:고아라 배우
# ======>3:성홍일 배우
# ======>4:한은선 배우
# ======>5:형슬우 배우
# ======>6:박상훈 배우
# ======>7:최정현 배우
# ======>1:박상훈 배우
# ======>2:최정현 배우
# ======>3:이민지 배우
# ======>4:김지호 배우
# ======>5:윤연경 배우
# ======>6:김지수 배우
# ======>7:양준모 배우
# ======>1:이해선 배우
# ======>2:배진웅 배우
# ======>3:윤종빈 배우
# ======>4:허미동 배우
# ======>5:박정범 배우
# ======>6:손병욱 배우
# ======>7:이하나 배우
# ======>1:손병욱 배우
# ======>2:이하나 배우
# ======>3:전현경 배우
# ======>4:오만석 배우
# ======>5:도용구 배우
# ======>6:최선자 배우
# ======>7:방은정 배우
# ======>1:오만석 배우
# ======>2:도용구 배우
# ======>3:최선자 배우
# ======>4:방은정 배우
# ======>5:류승곤 배우
# ======>6:김현준 배우
# ======>7:문태선 배우
# ======>1:강예서 배우
# ======>2:오영화 배우
# ======>3:임형태 배우
# ======>4:김진구 배우
# ======>5:방성자 배우
# ======>6:김현준 배우
# ======>7:문태선 배우
# ======>1:방성자 배우
# ======>2:김현준 배우
# ======>3:문태선 배우
# ======>4:한재덕 배우
# ======>5:홍예서 배우
# ======>6:정성모 배우
# ======>7:김혜은 배우
# ======>1:김민규 배우
# ======>2:김정화 배우
# ======>3:김영선 배우
# ======>4:박성택 배우
# ======>5:안지혜 배우
# ======>6:이은실 배우
# ======>7:박순동 배우
# ======>1:심혜진 배우
# ======>2:여민주 배우
# ======>3:정성모 배우
# ======>4:최은애 배우
# ======>5:장훈 배우
# ======>6:반민정 배우
# ======>7:김도은 배우
# ======>1:최문자 배우
# ======>2:김내현 배우
# ======>3:박영수 배우
# ======>4:홍은택 배우
# ======>5:장윤주 배우
# ======>6:황병국 배우
# ======>7:박용철 배우
# ======>1:윤희석 배우
# ======>2:주현 배우
# ======>3:김도엽 배우
# ======>4:박진우 배우
# ======>5:양춘 배우
# ======>6:조은주 배우
# ======>7:정현 배우
# ======>1:서영주 배우
# ======>2:이광기 배우
# ======>3:이인세 배우
# ======>4:장남부 배우
# ======>5:박동룡 배우
# ======>6:전영선 배우
# ======>7:김세원 배우
# ======>1:김세원 배우
# ======>2:서신애 배우
# ======>3:강미애 배우
# ======>4:강영구 배우
# ======>5:박영빈 배우
# ======>6:서영춘 배우
# ======>7:조성희 배우
# ======>1:이준 배우
# ======>2:송경의 배우
# ======>3:김지유 배우
# ======>4:홍승철 배우
# ======>5:김진규 배우
# ======>6:장준휘 배우
# ======>7:유인영 배우
# ======>1:김현빈 배우
# ======>2:지이수 배우
# ======>3:이현우 배우
# ======>4:윤주상 배우
# ======>5:민영 배우
# ======>6:강재철 배우
# ======>7:이지현 배우
# ======>1:이호재 배우
# ======>2:정수정 배우
# ======>3:배호근 배우
# ======>4:이은주 배우
# ======>5:임양 배우
# ======>6:성민철 배우
# ======>7:윤소정 배우
# ======>1:윤양하 배우
# ======>2:이현우 배우
# ======>3:연준석 배우
# ======>4:이영진 배우
# ======>5:김수경 배우
# ======>6:서윤아 배우
# ======>7:김신명 배우
# ======>1:권혁풍 배우
# ======>2:김최용준 배우
# ======>3:이민우 배우
# ======>4:조관우 배우
# ======>5:백황기 배우
# ======>6:이영미 배우
# ======>7:한혜진 배우
# ======>1:추귀정 배우
# ======>2:최제우 배우
# ======>3:염상태 배우
# ======>4:조재현 배우
# ======>5:서리나 배우
# ======>6:황미영 배우
# ======>7:강백수 배우
# ======>1:서강준 배우
# ======>2:박규채 배우
# ======>3:고경표 배우
# ======>4:최민규 배우
# ======>5:이기영 배우
# ======>6:권영국 배우
# ======>7:강지우 배우
# ======>1:서동수 배우
# ======>2:하윤경 배우
# ======>3:공지영 배우
# ======>4:노진원 배우
# ======>5:장성윤 배우
# ======>6:유대형 배우
# ======>7:현석 배우
# ======>1:이종국 배우
# ======>2:홍경인 배우
# ======>3:민윤재 배우
# ======>4:남태부 배우
# ======>5:이해영 배우
# ======>6:김예원 배우
# ======>7:전수진 배우
# ======>1:유대형 배우
# ======>2:현석 배우
# ======>3:조학자 배우
# ======>4:유걸 배우
# ======>5:최용진 배우
# ======>6:조민기 배우
# ======>7:최강희 배우
# ======>1:나영희 배우
# ======>2:조향기 배우
# ======>3:이주연 배우
# ======>4:구웅서 배우
# ======>5:이달형 배우
# ======>6:주아름 배우
# ======>7:이재준 배우
# ======>1:유걸 배우
# ======>2:최용진 배우
# ======>3:최강희 배우
# ======>4:조민기 배우
# ======>5:이요원 배우
# ======>6:이완 배우
# ======>7:신찬일 배우
# ======>1:이요원 배우
# ======>2:허기호 배우
# ======>3:이소영 배우
# ======>4:박은숙 배우
# ======>5:윤가현 배우
# ======>6:이향 배우
# ======>7:정기섭 배우
# ======>1:정기섭 배우
# ======>2:홍다미 배우
# ======>3:김해인 배우
# ======>4:이장우 배우
# ======>5:주상욱 배우
# ======>6:홍윤정 배우
# ======>7:안병경 배우
# ======>1:노민우 배우
# ======>2:유민규 배우
# ======>3:시우민 배우
# ======>4:이경민 배우
# ======>5:오연아 배우
# ======>6:임상수 배우
# ======>7:조덕제 배우
# ======>1:서준영 배우
# ======>2:김주현 배우
# ======>3:전숙 배우
# ======>4:노민우 배우
# ======>5:유민규 배우
# ======>6:시우민 배우
# ======>7:이경민 배우
# ======>1:변기종 배우
# ======>2:유화춘 배우
# ======>3:이현우 배우
# ======>4:오연서 배우
# ======>5:고현정 배우
# ======>6:최희진 배우
# ======>7:안용욱 배우
# --->300페이지 출력됨
# ======>1:김영환 배우
# ======>2:이재현 배우
# ======>3:박웅 배우
# ======>4:오미희 배우
# ======>5:지수 배우
# ======>6:조윤희 배우
# ======>7:이정비 배우
# ======>1:오미희 배우
# ======>2:김영환 배우
# ======>3:이재현 배우
# ======>4:지수 배우
# ======>5:이정비 배우
# ======>6:조윤희 배우
# ======>7:권윤덕 배우
# ======>1:오미희 배우
# ======>2:지수 배우
# ======>3:조윤희 배우
# ======>4:이정비 배우
# ======>5:문근영 배우
# ======>6:권윤덕 배우
# ======>7:유화춘 배우
# ======>1:김세동 배우
# ======>2:임필성 배우
# ======>3:김수환 배우
# ======>4:이바울 배우
# ======>5:남미리 배우
# ======>6:김하나 배우
# ======>7:장정인 배우
# ======>1:강호철 배우
# ======>2:이낙훈 배우
# ======>3:이환 배우
# ======>4:이휘향 배우
# ======>5:천민희 배우
# ======>6:이윤지 배우
# ======>7:송옥숙 배우
# ======>1:강호철 배우
# ======>2:이낙훈 배우
# ======>3:이환 배우
# ======>4:천민희 배우
# ======>5:이휘향 배우
# ======>6:이윤지 배우
# ======>7:송옥숙 배우
# ======>1:장현성 배우
# ======>2:이현학 배우
# ======>3:이동호 배우
# ======>4:권하서 배우
# ======>5:김일우 배우
# ======>6:이승준 배우
# ======>7:이준동 배우
# ======>1:김민교 배우
# ======>2:지대한 배우
# ======>3:조성하 배우
# ======>4:이주승 배우
# ======>5:하재숙 배우
# ======>6:김형태 배우
# ======>7:이찬희 배우
# ======>1:이정원 배우
# ======>2:송두율 배우
# ======>3:여호민 배우
# ======>4:유퉁 배우
# ======>5:강태우 배우
# ======>6:김민교 배우
# ======>7:지대한 배우
# ======>1:김일우 배우
# ======>2:이승준 배우
# ======>3:이준동 배우
# ======>4:채연희 배우
# ======>5:김금화 배우
# ======>6:안도규 배우
# ======>7:이동욱 배우
# ======>1:탁현민 배우
# ======>2:차순형 배우
# ======>3:고아라 배우
# ======>4:이현 배우
# ======>5:박주희 배우
# ======>6:반효정 배우
# ======>7:홍윤정 배우
# ======>1:김은혜 배우
# ======>2:윤미나 배우
# ======>3:이경미 배우
# ======>4:이업동 배우
# ======>5:이양희 배우
# ======>6:최화정 배우
# ======>7:이수현 배우
# ======>1:방은진 배우
# ======>2:이석구 배우
# ======>3:박은혜 배우
# ======>4:안미나 배우
# ======>5:최윤빈 배우
# ======>6:정진수 배우
# ======>7:오용 배우
# ======>1:윤미나 배우
# ======>2:이업동 배우
# ======>3:이양희 배우
# ======>4:최화정 배우
# ======>5:이수현 배우
# ======>6:백승익 배우
# ======>7:황신혜 배우
# ======>1:한하나 배우
# ======>2:배창복 배우
# ======>3:김보경 배우
# ======>4:정기선 배우
# ======>5:현서영 배우
# ======>6:김은혜 배우
# ======>7:지용석 배우
# ======>1:박선희 배우
# ======>2:백동현 배우
# ======>3:윤종석 배우
# ======>4:현숙희 배우
# ======>5:조하석 배우
# ======>6:김진우 배우
# ======>7:연상호 배우
# ======>1:김혜인 배우
# ======>2:김유리 배우
# ======>3:염현준 배우
# ======>4:남경읍 배우
# ======>5:조금앵 배우
# ======>6:양진성 배우
# ======>7:유민채 배우
# ======>1:유민채 배우
# ======>2:김소숙 배우
# ======>3:성정선 배우
# ======>4:이영은 배우
# ======>5:이민우 배우
# ======>6:지용석 배우
# ======>7:고선애 배우
# ======>1:길달호 배우
# ======>2:현석 배우
# ======>3:최배영 배우
# ======>4:이시원 배우
# ======>5:김혜인 배우
# ======>6:염현준 배우
# ======>7:남경읍 배우
# ======>1:김소라 배우
# ======>2:이영 배우
# ======>3:심이영 배우
# ======>4:현석 배우
# ======>5:길달호 배우
# ======>6:최배영 배우
# ======>7:이시원 배우
# ======>1:이민우 배우
# ======>2:이은성 배우
# ======>3:전국환 배우
# ======>4:정솔 배우
# ======>5:김용학 배우
# ======>6:고인범 배우
# ======>7:박지수 배우
# ======>1:박혜숙 배우
# ======>2:명승훈 배우
# ======>3:이은성 배우
# ======>4:정솔 배우
# ======>5:전국환 배우
# ======>6:김용학 배우
# ======>7:고인범 배우
# ======>1:다나 배우
# ======>2:김유미 배우
# ======>3:박혜숙 배우
# ======>4:명승훈 배우
# ======>5:이은성 배우
# ======>6:전국환 배우
# ======>7:정솔 배우
# ======>1:김용학 배우
# ======>2:고인범 배우
# ======>3:박지수 배우
# ======>4:이빛나 배우
# ======>5:장준학 배우
# ======>6:심원철 배우
# ======>7:김혜정 배우
# ======>1:유강진 배우
# ======>2:유광수 배우
# ======>3:장유상 배우
# ======>4:박유환 배우
# ======>5:윤문식 배우
# ======>6:윤영균 배우
# ======>7:황성민 배우
# ======>1:유강진 배우
# ======>2:윤문식 배우
# ======>3:윤영균 배우
# ======>4:황성민 배우
# ======>5:박유환 배우
# ======>6:오기환 배우
# ======>7:전원주 배우
# ======>1:심원철 배우
# ======>2:김혜정 배우
# ======>3:왕지원 배우
# ======>4:리민 배우
# ======>5:임정은 배우
# ======>6:서이안 배우
# ======>7:유순철 배우
# ======>1:배창호 배우
# ======>2:권현상 배우
# ======>3:허지원 배우
# ======>4:이선구 배우
# ======>5:김병철 배우
# ======>6:국정환 배우
# ======>7:윤정희 배우
# ======>1:김수천 배우
# ======>2:석인수 배우
# ======>3:허정은 배우
# ======>4:배창호 배우
# ======>5:허지원 배우
# ======>6:이선구 배우
# ======>7:김병철 배우
# ======>1:이민정 배우
# ======>2:한성수 배우
# ======>3:남철 배우
# ======>4:윤대열 배우
# ======>5:지윤호 배우
# ======>6:이승훈 배우
# ======>7:박성준 배우
# ======>1:임정은 배우
# ======>2:백승환 배우
# ======>3:손창민 배우
# ======>4:김용옥 배우
# ======>5:이경희 배우
# ======>6:조영각 배우
# ======>7:신재하 배우
# ======>1:이미소 배우
# ======>2:최성원 배우
# ======>3:송이우 배우
# ======>4:김영옥 배우
# ======>5:유수미 배우
# ======>6:신상옥 배우
# ======>7:이승현 배우
# ======>1:신재휘 배우
# ======>2:요조 배우
# ======>3:권성덕 배우
# ======>4:이예민 배우
# ======>5:정원 배우
# ======>6:김도현 배우
# ======>7:추석양 배우
# ======>1:김권후 배우
# ======>2:정선경 배우
# ======>3:김지영 배우
# ======>4:송삼동 배우
# ======>5:하유미 배우
# ======>6:소이 배우
# ======>7:김강민 배우
# ======>1:최진리 배우
# ======>2:이호재 배우
# ======>3:임승대 배우
# ======>4:조성근 배우
# ======>5:강지환 배우
# ======>6:임호 배우
# ======>7:신재휘 배우
# ======>1:김자영 배우
# ======>2:이경희 배우
# ======>3:백승환 배우
# ======>4:손창민 배우
# ======>5:김용옥 배우
# ======>6:조영각 배우
# ======>7:신재하 배우
# ======>1:이경희 배우
# ======>2:백승환 배우
# ======>3:조영각 배우
# ======>4:신재하 배우
# ======>5:김용순 배우
# ======>6:이동신 배우
# ======>7:안세하 배우
# ======>1:이호재 배우
# ======>2:조성근 배우
# ======>3:강지환 배우
# ======>4:임승대 배우
# ======>5:임호 배우
# ======>6:신재휘 배우
# ======>7:요조 배우
# ======>1:신동엽 배우
# ======>2:김용옥 배우
# ======>3:이경희 배우
# ======>4:백승환 배우
# ======>5:손창민 배우
# ======>6:조영각 배우
# ======>7:김용훈 배우
# ======>1:김은하 배우
# ======>2:한영수 배우
# ======>3:이진석 배우
# ======>4:이동규 배우
# ======>5:김세정 배우
# ======>6:김진혁 배우
# ======>7:이현순 배우
# ======>1:문혜인 배우
# ======>2:이소연 배우
# ======>3:신운섭 배우
# ======>4:이세미 배우
# ======>5:김민석 배우
# ======>6:한신화 배우
# ======>7:노브레인 배우
# ======>1:조형기 배우
# ======>2:윤세현 배우
# ======>3:경성환 배우
# ======>4:최권 배우
# ======>5:박영서 배우
# ======>6:이민아 배우
# ======>7:우기홍 배우
# ======>1:신성균 배우
# ======>2:윤은지 배우
# ======>3:김민종 배우
# ======>4:박미숙 배우
# ======>5:문세윤 배우
# ======>6:최은석 배우
# ======>7:이란희 배우
# ======>1:최권 배우
# ======>2:박영서 배우
# ======>3:이민아 배우
# ======>4:경성환 배우
# ======>5:김민경 배우
# ======>6:김순자 배우
# ======>7:우기홍 배우
# ======>1:한소현 배우
# ======>2:오성태 배우
# ======>3:김이정 배우
# ======>4:양일민 배우
# ======>5:오나라 배우
# ======>6:염동헌 배우
# ======>7:이화룡 배우
# ======>1:유명순 배우
# ======>2:이현진 배우
# ======>3:주예린 배우
# ======>4:조혜주 배우
# ======>5:이선진 배우
# ======>6:김추련 배우
# ======>7:최숙진 배우
# ======>1:현길수 배우
# ======>2:김추련 배우
# ======>3:최숙진 배우
# ======>4:주영호 배우
# ======>5:남상지 배우
# ======>6:최원경 배우
# ======>7:김준원 배우
# ======>1:김진혁 배우
# ======>2:이현순 배우
# ======>3:박도연 배우
# ======>4:
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# ">
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
#  배우
# ======>5:강덕경 배우
# ======>6:한소현 배우
# ======>7:박유밀 배우
# ======>1:오성태 배우
# ======>2:김이정 배우
# ======>3:양일민 배우
# ======>4:오나라 배우
# ======>5:염동헌 배우
# ======>6:이화룡 배우
# ======>7:유명순 배우
# ======>1:백영민 배우
# ======>2:류제승 배우
# ======>3:봉준호 배우
# ======>4:한혜숙 배우
# ======>5:이언 배우
# ======>6:이재원 배우
# ======>7:주유랑 배우
# --->350페이지 출력됨
# ======>1:최성원 배우
# ======>2:최재호 배우
# ======>3:공정환 배우
# ======>4:정보석 배우
# ======>5:한소룡 배우
# ======>6:이상아 배우
# ======>7:신지훈 배우
# ======>1:김기종 배우
# ======>2:백영민 배우
# ======>3:류제승 배우
# ======>4:봉준호 배우
# ======>5:한혜숙 배우
# ======>6:이언 배우
# ======>7:이재원 배우
# ======>1:김민경 배우
# 2458

# %%
for actor in actor_detail_list:
    if len(actor['배우이름'])>10:
        print(actor)
# Out:
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n', '랭킹': 355, '흥행지수': '416', '출연영화': ['임프랙티컬 조커스: 더 무비', '리브레스', '미나리']}
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n', '랭킹': 1070, '흥행지수': '4', '출연영화': ['라이크 어 보스', '메모리 이레이저', '임프랙티컬 조커스: 더 무비']}
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n', '랭킹': 1567, '흥행지수': '1', '출연영화': ['라이크 어 보스', '메모리 이레이저', '임프랙티컬 조커스: 더 무비']}
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n', '랭킹': 1690, '흥행지수': '0', '출연영화': ['라이크 어 보스', '메모리 이레이저', '임프랙티컬 조커스: 더 무비']}
# {'배우이름': '\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n">\n\n\n\n\n씨네21\n\n\n\n\n\n\n\n\n\n서비스 이용에 불편을 드려 죄송합니다.\n일시적으로 서비스 장애가 발생하였습니다.\n빠른 시간안에 복구하도록 하겠습니다.\n\t\t\t\n\n\n\n\n\n', '랭킹': 2426, '흥행지수': '0', '출연영화': ['라이크 어 보스', '메모리 이레이저', '임프랙티컬 조커스: 더 무비']}

# %%
print('before',len(actor_detail_list))
actor_detail_final_list=[actor for actor in actor_detail_list if len(actor['배우이름'])<10]
print('after',len(actor_detail_final_list))
# Out:
# before 2458
# after 2453

# %% [markdown]
# ### 5단계
# * actor_detail_final_list를 actors.json 파일로 저장하기

# %%
import json

with open('data/actors.json','w',encoding='utf8') as file:
    json.dump(actor_detail_final_list,file)
    
print('json file write 종료')
# Out:
# json file write 종료

# %%
with open('data/actors.json','r',encoding='utf8') as file:
    json_data= json.load(file)
print(json_data)
# Out:
# [{'배우이름': '이병헌', '랭킹': 1, '흥행지수': '21,485', '다른 이름': 'Byung-hun Lee;BH Lee', '직업': '배우', '생년월일': '1970-07-12', '성별': '남', '홈페이지': 'http://www.leebyunghun.kr/', '신장/체중': '177cm, 72kg', '학교': '한양대학교 불어문학과', '취미': '모자수집, 여행', '특기': '태권도, 스노우보드, 수영, 팔씨름', '출연영화': ['비상선언', '콘크리트 유토피아', '백두산']}, {'배우이름': '진선규', '랭킹': 2, '흥행지수': '19,117', '직업': '배우', '생년월일': '1977-09-13', '성별': '남', '출연영화': ['카운트(가제)', '킹덤 시즌 2', '사바하']}, {'배우이름': '하정우', '랭킹': 3, '흥행지수': '17,589', '다른 이름': '김성훈; 河正宇', '직업': '배우', '생년월일': '1978-03-11', '성별': '남', '홈페이지': 'https://www.facebook.com/ft.hajungwoo', '신장/체중': '184cm, 75kg', '학교': '중앙대학교 연극학 학사', '취미': '피아노, 검도, 수영', '출연영화': ['클로젯', '백두산', 'PMC: 더 벙커']}, {'배우이름': '마동석', '랭킹': 4, '흥행지수': '17,347', '다른 이름': 'Ma Dongseok', '직업': '배우', '생년월일': '1971-03-01', '성별': '남', '홈페이지': 'https://www.instagram.com/madongseok_/https://twitter.com/madongseok12', '신장/체중': '178cm, 100kg', '출연영화': ['시동', '나쁜 녀석들: 더 무비', '백두산']}, {'배우이름': '이하늬', '랭킹': 5, '흥행지수': '15,922', '직업': '배우', '생년월일': '1983-03-02', '성별': '여', '홈페이지': 'https://www.facebook.com/saram.leehoneyhttps://instagram.com/honey_lee32/', '출연영화': ['블랙머니', '열혈사제', '극한직업']}, {'배우이름': '류승룡', '랭킹': 6, '흥행지수': '14,039', '다른 이름': '류승용; 유승룡', '직업': '배우', '생년월일': '1970-11-29', '성별': '남', '신장/체중': '175cm, 72kg', '학교': '서울예술대학 연극', '소속사': '필름있수다', '출연영화': ['휴머니멀', '킹덤 시즌 2', '입술은 안돼요(가제)']}, {'배우이름': '유해진', '랭킹': 7, '흥행지수': '13,699', '직업': '배우', '생년월일': '1969-01-04', '성별': '남', '신장/체중': '174cm, 65kg', '학교': '서울예술대학 연극과', '소속사': '심엔터테인먼트', '출연영화': ['휴머니멀', '삼시세끼 어촌편 5', '봉오동 전투']}, {'배우이름': '박정민', '랭킹': 8, '흥행지수': '12,984', '직업': '배우', '생년월일': '1987-02-25', '성별': '남', '신장/체중': '178cm, 63kg', '학교': '한국예술종합학교 영상원 연극원 연기과', '출연영화': ['사냥의 시간', '다만 악에서 구하소서', '사바하']}, {'배우이름': '황정민', '랭킹': 9, '흥행지수': '12,870', '직업': '배우', '생년월일': '1970-09-01', '성별': '남', '신장/체중': '180cm, 75kg', '학교': '서울예술대학 연극과 졸업', '특기': '농구, 악기연주', '소속사': '예당엔터테인먼트', '출연영화': ['다만 악에서 구하소서', '교섭', '공작']}, {'배우이름': '송강호', '랭킹': 10, '흥행지수': '12,437', '직업': '배우', '생년월일': '1967-01-17', '성별': '남', '신장/체중': '180cm, 80kg', '학교': '부산경상대학 방송연예', '소속사': '호두엔터테인먼트', '출연영화': ['브로커(가제)', '비상선언', '기생충']}, {'배우이름': '조진웅', '랭킹': 11, '흥행지수': '11,855', '다른 이름': '조원준', '직업': '배우', '생년월일': '1976-03-03', '성별': '남', '홈페이지': 'http://www.facebook.com/saram.chojinwoong', '신장/체중': '185cm, 98kg', '학교': '경성대학교 연극영화', '특기': '진도 북춤', '소속사': '㈜사람엔터테인먼트', '출연영화': ['경관의 피(가제)', '대외비: 권력의 탄생(가제)', '광대들: 풍문조작단']}, {'배우이름': '신하균', '랭킹': 12, '흥행지수': '11,179', '직업': '배우', '생년월일': '1974-05-30', '성별': '남', '신장/체중': '175cm, 67kg', '학교': '서울예술대학 방송연예학', '출연영화': ['영혼수선공', '선물', '미스터 주: 사라진 VIP']}, {'배우이름': '조우진', '랭킹': 13, '흥행지수': '10,914', '다른 이름': '조신제', '직업': '배우', '생년월일': '1979-01-16', '성별': '남', '출연영화': ['도굴', '서복', '봉오동 전투']}, {'배우이름': '이동휘', '랭킹': 14, '흥행지수': '10,778', '직업': '배우', '생년월일': '1985-07-22', '성별': '남', '홈페이지': 'https://www.instagram.com/dlehdgnl/', '출연영화': ['콜', '시네마틱드라마 SF8 -  만신', '시네마틱드라마 SF8']}, {'배우이름': '이정재', '랭킹': 15, '흥행지수': '10,620', '직업': '배우', '성별': '남', '홈페이지': 'http://www.artistcompany.co.kr/portfolio-item/lee-jung-jae/', '소속사': '아티스트컴퍼니', '출연영화': ['다만 악에서 구하소서', '사바하', '보좌관 – 세상을 움직이는 사람들']}, {'배우이름': '전혜진', '랭킹': 16, '흥행지수': '10,189', '다른 이름': '전이다', '직업': '배우', '생년월일': '1976-08-10', '성별': '여', '신장/체중': '171cm, 49kg', '학교': '상명대학교 영화과', '취미': '영화감상, 노래 부르기', '특기': '수영', '소속사': '호두엔터테인먼트', '출연영화': ['비밀의 숲 2', '백두산', '검색어를 입력하세요 WWW']}, {'배우이름': '염정아', '랭킹': 17, '흥행지수': '9,943', '직업': '배우', '성별': '여', '홈페이지': 'http://www.artistcompany.co.kr/portfolio-item/yum-jung-ah/', '소속사': '아티스트컴퍼니', '출연영화': ['삼시세끼 산촌편', '시동', '강철비2: 정상회담']}, {'배우이름': '공명', '랭킹': 18, '흥행지수': '9,640', '다른 이름': '서프라이즈; 김동현', '직업': '배우', '생년월일': '1994-05-26', '성별': '남', '홈페이지': 'https://instagram.com/gongmyoung0526/', '출연영화': ['한산: 용의 출현', '행복의 진수', '행복의 진수']}, {'배우이름': '장혜진', '랭킹': 19, '흥행지수': '9,516', '직업': '배우', '생년월일': '1975-09-05', '성별': '여', '출연영화': ['애비규환', '계약우정', '출사표']}, {'배우이름': '이선균', '랭킹': 20, '흥행지수': '9,095', '직업': '배우', '생년월일': '1975-03-02', '성별 ...

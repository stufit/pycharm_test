# %%
pip show lxml

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import os

url = 'http://www.podbbang.com/_m_api/podcasts/16524/episodes?offset=0&sort=pubdate:desc&episode_id=0&limit=8&with=summary&cache=0'

res = requests.get(url)
print(res.status_code)
if res.ok:
    #lxml 파서를 사용해서 BeautifulSoup 객체생성
    soup = BeautifulSoup(res.text,'lxml')
    print(soup)
    #<p> </p> 사이의 text를 추출함
    p_tag = soup.select('p')[0].text
    
    #str 타입의 텍스트를 dict 타입으로 변경하기 위해서 json 내부모듈을 사용함
    json_data = json.loads(p_tag)
    #print(type(json_data), json_data)
    
    #{data:[{},{},{}]}
    episode_length = len(json_data['data'])
    #print(len(json_data['data']),type(json_data['data']))
    episode_list = json_data['data']      
    
    for episode in episode_list:
        print('------')
        #에피소드의 제목
        title = episode['title']
        #에피소드 다운로드 url
        mp3_url = episode['enclosure']['url']
        print(title, mp3_url)
        
        #url 값이 있으면 다운로드 받아야 함
        if mp3_url:
            
            req_header = {
                'referer':'http://www.podbbang.com/ch/16255',
                'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
            }
            
            dir_name = os.path.join('mp3','여바라')
            print(dir_name) #mp3\여바라
            
            #해당 디렉토리가 없으면
            if not os.path.isdir(dir_name):
                #디렉토리를 생성
                os.makedirs(dir_name)
            
            #해당 url에서 파일명만 추출
            file_name = os.path.basename(mp3_url)
            #생성된 디렉토리명과 파일명을 합쳐주기
            file_name = dir_name+'/'+file_name
            
            #print(file_name)
            res = requests.get(mp3_url, headers=req_header)
            if res.ok:
                #response 객체에서 binary 데이터 추출
                mp3_bin = res.content                
                #binary 데이터를 local 파일로 저장
                with open(file_name, 'wb') as file:
                    file.write(mp3_bin)
# Out:
# 200
# <html><body><p>{"data":[{"id":23448927,"podcast":{"id":16524},"title":"120\ud68c \uc5b5\uc9c0\ub85c \uae30\ubd84 \ub098\uc544\uc9c0\uac8c \ud558\uc9c0 \ub9d9\uc2dc\ub2e4","description":"\uc9e7\uc740 \uc601\uc0c1\uc774\uc9c0\ub9cc \ub3c4\uc6c0\ub418\uc2dc\uae38 \ubc14\ub798\ubd05\ub2c8\ub2e4. \n\n*\uc601\uc0c1\uc73c\ub85c \ubcf4\uc2dc\ub824\uba74: https:\/\/www.youtube.com\/channel\/UCc-zCCulW6jq1lmWjlKCUkw\n\n\n*\ub9e4\uc77c \uc544\uce68 \ud798\uc774\ub418\ub294 \uc601\uc5b4 \uacf5\ubd80 \uc18c\uc6b8\uc601\uc5b4 \uad6c\ub3c5: http:\/\/pf.kakao.com\/_pxixkRxb\n\uc544\uce68 8\uc2dc\uc5d0 \ud798\uc774 \ub0b4\ub294 3\ubd84 \uc601\uc5b4 \ucf58\ud150\uce20\ub97c \ubcf4\ub0b4\ub4dc\ub9ac\ub294 \uc77c\uac04 \uc5d0\uc11c\ub294 \n4\uc6d4\uc5d0\ub294 \ubbf8\ub4dc, \uc601\ud654 \ubfd0 \uc544\ub2c8\ub77c \ucf54\ub85c\ub098 \ubc14\uc774\ub7ec\uc2a4\uc758 \uc704\uae30 \uc18d\uc5d0\uc11c \ub3c4\uc6c0\uc774 \ub418\ub
"published_at":"2020-03-30 13:18:20"},{"id":23400496,"podcast":{"id":16524},"title":"118\ud68c \uc774\ub7f0 \ucf5c\ub77c\ubcf4 \uc6c3\uc74c \ud3ed\ud0c4, \uc601\uc5b4 \uc544\uc6c3 \uc624\ube0c \uc548\uc911 \uc8fc\uc758","description":"\uc640 \uc744 \uc6b0\ub9ac \ub9d8\ub300\ub85c \ucf5c\ub77c\ubcf4. \n\uc798\uac00\uc694. \uc774\uc815\ud601 \ub3d9\uc9c0! \uc544\ub4c0!\n\n\ucf54\ub85c\ub098\ub85c \ub2e4\uc6b4\ub41c \uae30\ubd84 \ucc45\uc784\uc9d1\ub2c8\ub2e4\uc694. \n\n*\uc601\uc5b4 \ubb38\uc7a5\n\uadf8\uac83\uc774 \uc6b0\ub9ac\ub97c \ud568\uaed8 \ud558\uac8c \ud588\ub2e4 That brought us together. \n\ub098\ub294 \uc0c1\ucc98(\uacb0\ud568)\uc774 \ub9ce\ub2e4. I have a lot of flaws. \n\n\n\uce74\ud1a1 \ucc44\ub110\uc5d0\uc11c \u2018\uc77c\uac04 \uc18c\uc6b8\uc601\uc5b4\u2019\ub97c \uac80\uc0c9\ud574\ubcf4\uc138\uc694. \n\uc601\uc5b4 \ucf58\ud150\uce20\ub294 \uc77 ...
# ------
# 120회 억지로 기분 나아지게 하지 맙시다 https://file.ssenhosting.com/data1/pb_22419/watchthegrass.mp3
# mp3/여바라
# ------
# 119회 한국 코로나 대응에 대한 외신 뉴스와 반응 https://file.ssenhosting.com/data1/pb_22419/74overseasnews.mp3
# mp3/여바라
# ------
# 118회 이런 콜라보 웃음 폭탄, 영어 아웃 오브 안중 주의 https://file.ssenhosting.com/data1/pb_22419/hand2020226.mp3
# mp3/여바라
# ------
# 117회 넷플릭스 본다면 이거슨 꿀팁 '나 홀로 그대' 공동구매각 https://file.ssenhosting.com/data1/pb_22419/handholo1.mp3
# mp3/여바라
# ------
# 116회 넌 라면먹을 계획이 다 있구나, 라끼남 맛 감탄을 영어로 https://file.ssenhosting.com/data1/pb_22419/hand2012.mp3
# mp3/여바라
# ------
# 115회 일간  삶이 전쟁터 같을 때 https://file.ssenhosting.com/data1/pb_22419/souleng7.mp3
# mp3/여바라
# ------
# 114회 라떼 이즈 홀스, 꼰대 선배를 대하는 임진주 작가, 멜로가 체질 2탄 https://file.ssenhosting.com/data1/pb_22419/handmelo2.mp3
# mp3/여바라
# ------
# 113회 [고민사연] 어른이 되었지만 여전히 어설픈 나를 만날 때 https://file.ssenhosting.com/data1/pb_22419/mid7.mp3
# mp3/여바라

# %% [markdown]
# ### 팟빵 다운로드 1단계
# * 팟빵 id 와 제목을 함수의 인자로 받는다.
# * 첫번째의 8개의 에피소드만 다운로드 받고 있다.
# * 저장되는 mp3 파일명을 에피소드의 타이틀로 설정함

# %%
#문자열에 있는 특수문자를 제거하는 함수
def clean_text(text):
    import re
    text = text.replace("\n", "")
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]','', text)
    cleaned_text = cleaned_text.replace(' ','')
    return cleaned_text

# %%
clean_text("김영철의 파워FM - 진짜 미국식 영어 810회 - 타일러의 진짜 미국식 영어 = Don't be so stubborn. = 억지 좀 부리지 마세요!!")
# Out:
# '김영철의파워FM진짜미국식영어810회타일러의진짜미국식영어Dontbesostubborn억지좀부리지마세요'

# %%
def podbbang_download(pod_id, title):
    import requests
    from bs4 import BeautifulSoup
    from urllib.parse import urljoin
    import json
    import os

    url = f'http://www.podbbang.com/_m_api/podcasts/{pod_id}/episodes'
    req_param = {
        "offset":0,
        "sort":"pubdate:desc",
        "episode_id":0,
        "limit":8,
        "with":"summary",
        "cache":0        
    }

    res = requests.get(url, params=req_param)
    print(res.status_code)
    if res.ok:
        #lxml 파서를 사용해서 BeautifulSoup 객체생성
        soup = BeautifulSoup(res.text,'lxml')
        #print(soup)
        #<p> </p> 사이의 text를 추출함
        p_tag = soup.select('p')[0].text

        #str 타입의 텍스트를 dict 타입으로 변경하기 위해서 json 내부모듈을 사용함
        json_data = json.loads(p_tag)
        #print(type(json_data), json_data)

        #{data:[{},{},{}]}
        episode_length = len(json_data['data'])
        #print(len(json_data['data']),type(json_data['data']))
        episode_list = json_data['data']      

        for episode in episode_list:
            print('------')
            #에피소드의 제목
            episode_title = episode['title']
            #에피소드 다운로드 url
            mp3_url = episode['enclosure']['url']
            print(episode_title, mp3_url)

            #url 값이 있으면 다운로드 받아야 함
            if mp3_url:

                req_header = {
                    'referer':f'http://www.podbbang.com/ch/{pod_id}',
                    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
                }

                dir_name = os.path.join('mp3',title)
                print(dir_name) #mp3\여바라

                #해당 디렉토리가 없으면
                if not os.path.isdir(dir_name):
                    #디렉토리를 생성
                    os.makedirs(dir_name)

                #해당 url에서 파일명만 추출
                #file_name = os.path.basename(mp3_url)
                episode_title = clean_text(episode_title)
                file_name = f'{episode_title}.mp3'
                
                #생성된 디렉토리명과 파일명을 합쳐주기
                file_name = dir_name+'/'+file_name

                #print(file_name)
                res = requests.get(mp3_url, headers=req_header)
                if res.ok:
                    #response 객체에서 binary 데이터 추출
                    mp3_bin = res.content                
                    #binary 데이터를 local 파일로 저장
                    with open(file_name, 'wb') as file:
                        file.write(mp3_bin)

# %% [markdown]
# ### 팟빵 다운로드 2단계
# * 팟빵 id 와 제목을 함수의 인자로 받는다.
# * 저장되는 mp3 파일명을 에피소드의 타이틀로 설정함
# * 모든 에피소드를 다운로드 받는다.
#  - 에피소드를 요청할때 offset 값의 최대값이 항상 변하므로
#  - itertools의 count() 함수를 사용해 무한루프를 수행하도록 한다.
#  - 무한루프를 빠져 나올수 있는 조건식을 반드시 주어야 한다.
#    - json_data['data'] 길이가 0 이면 무한루프를 탈출한다.
#  - 사람이 직접 다운로드 받는 것 처럼 보이게 하기 위해서 sleep time 설정한다.
#    - time이라는 내부모듈의 sleep함수를 사용한다.

# %%
def podbbang_download(pod_id, title):
    import requests
    from bs4 import BeautifulSoup
    from urllib.parse import urljoin
    import json
    import os
    from itertools import count
    from time import sleep

    url = f'http://www.podbbang.com/_m_api/podcasts/{pod_id}/episodes'
    
    
    for offset in count(0):
        
        req_param = {
            "offset":offset,
            "sort":"pubdate:desc",
            "episode_id":0,
            "limit":8,
            "with":"summary",
            "cache":0        
        }

        res = requests.get(url, params=req_param)
        print(res.status_code)
        if res.ok:
            #lxml 파서를 사용해서 BeautifulSoup 객체생성
            soup = BeautifulSoup(res.text,'lxml')
        #print(soup)
        #<p> </p> 사이의 text를 추출함
        p_tag = soup.select('p')[0].text

        #str 타입의 텍스트를 dict 타입으로 변경하기 위해서 json 내부모듈을 사용함
        json_data = json.loads(p_tag)
        #print(type(json_data), json_data)

        #{data:[{},{},{}]}
        episode_length = len(json_data['data'])
        #print(len(json_data['data']),type(json_data['data']))
        if episode_length ==0:
            return None
            
                
        episode_list = json_data['data']      

        for episode in episode_list:
            print('------')
            #에피소드의 제목
        episode_title = episode['title']
            #에피소드 다운로드 url
        mp3_url = episode['enclosure']['url']
        print(episode_title, mp3_url)

            #url 값이 있으면 다운로드 받아야 함
        if mp3_url:
            req_header = {
                    'referer':f'http://www.podbbang.com/ch/{pod_id}',
                    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
            }

            dir_name = os.path.join('mp3',title)
            print(dir_name) #mp3\여바라

                #해당 디렉토리가 없으면
            if not os.path.isdir(dir_name):
                    #디렉토리를 생성
                os.makedirs(dir_name)

                #해당 url에서 파일명만 추출
                #file_name = os.path.basename(mp3_url)
            episode_title = clean_text(episode_title)
            file_name = f'{episode_title}.mp3'
                
                #생성된 디렉토리명과 파일명을 합쳐주기
            file_name = dir_name+'/'+file_name

                #print(file_name)
            res = requests.get(mp3_url, headers=req_header)
            if res.ok:
                    #response 객체에서 binary 데이터 추출
                mp3_bin = res.content                
                    #binary 데이터를 local 파일로 저장
                with open(file_name, 'wb') as file:
                    file.write(mp3_bin)
                        
                    #0.5초간 프로세스를 중지함. 기계가 아니라 사람처럼 보이게 하려고
                sleep(0.5)

# %%
podbbang_download('11393','실비아멘토링')
# Out:
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# S2 Ep04. 운동화 끈 (ZAPATILLAS DE CORDONES)_한국어 https://file.ssenhosting.com/data1/silviaedu1/ZAPATILLASKOR2.mp3
# mp3/실비아멘토링
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# S2 Ep02.당신이 따뜻해서 봄이 왔습니다.  Porque tú eres cálido... https://file.ssenhosting.com/data1/silviaedu1/S2Ep02.mp3
# mp3/실비아멘토링
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# 실비아의 새로운 팟캐스트 '스페인어 스토리텔링'을 찾아주세요~~ https://file.ssenhosting.com/data1/silviaedu1/PodintroPPT01.pdf
# mp3/실비아멘토링
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# Ep 159. 대명사와 긍정명령형의 합체 https://file.ssenhosting.com/data1/silviaedu1/Ep159.mp3
# mp3/실비아멘토링
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# Ep 153. 접속법 과거완료 https://file.ssenhosting.com/data1/silviaedu1/Ep1531.mp3
# mp3/실비아멘토링
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# [마감] Noticia!! '11월의 여름밤' 오픈 파티에 초대합니다 https://file.ssenhosting.com/data1/silviaedu1/invito.pdf
# mp3/실비아멘토링
# 200
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# Ep 139. hay que + 동사원형 https://file.ssenhosting.com/data1/silviaedu1/Ep139.mp3
# mp3/실비아멘토링
# 200
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-24-dbb5fa956022> in <module>
# ----> 1 podbbang_download('11393','실비아멘토링')
#
# <ipython-input-22-21bc94bc8398> in podbbang_download(pod_id, title)
#      32
#      33         #str 타입의 텍스트를 dict 타입으로 변경하기 위해서 json 내부모듈을 사용함
# ---> 34         json_data = json.loads(p_tag)
#      35         #print(type(json_data), json_data)
#      36
#
# /opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 229 (char 228)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import os

url = 'http://www.podbbang.com/_m_api/podcasts/16524/episodes?offset=0&sort=pubdate:desc&episode_id=0&limit=8&with=summary&cache=0'

res = requests.get(url)
print(res.status_code)
if res.ok:
    #lxml 파서를 사용해서 BeautifulSoup 객체생성
    soup = BeautifulSoup(res.text,'lxml')
    print(soup)
    #<p> </p> 사이의 text를 추출함
    p_tag = soup.select('p')[0].text
    print('------------')
    
    #str 타입의 텍스트를 dict 타입으로 변경하기 위해서 json 내부모듈을 사용함
    json_data = json.loads(p_tag)
    print(type(json_data), json_data)
    
    #{data:[{},{},{}]}
    episode_length = len(json_data['data'])
    #print(len(json_data['data']),type(json_data['data']))
    episode_list = json_data['data']
# Out:
# 200
# <html><body><p>{"data":[{"id":23448927,"podcast":{"id":16524},"title":"120\ud68c \uc5b5\uc9c0\ub85c \uae30\ubd84 \ub098\uc544\uc9c0\uac8c \ud558\uc9c0 \ub9d9\uc2dc\ub2e4","description":"\uc9e7\uc740 \uc601\uc0c1\uc774\uc9c0\ub9cc \ub3c4\uc6c0\ub418\uc2dc\uae38 \ubc14\ub798\ubd05\ub2c8\ub2e4. \n\n*\uc601\uc0c1\uc73c\ub85c \ubcf4\uc2dc\ub824\uba74: https:\/\/www.youtube.com\/channel\/UCc-zCCulW6jq1lmWjlKCUkw\n\n\n*\ub9e4\uc77c \uc544\uce68 \ud798\uc774\ub418\ub294 \uc601\uc5b4 \uacf5\ubd80 \uc18c\uc6b8\uc601\uc5b4 \uad6c\ub3c5: http:\/\/pf.kakao.com\/_pxixkRxb\n\uc544\uce68 8\uc2dc\uc5d0 \ud798\uc774 \ub0b4\ub294 3\ubd84 \uc601\uc5b4 \ucf58\ud150\uce20\ub97c \ubcf4\ub0b4\ub4dc\ub9ac\ub294 \uc77c\uac04 \uc5d0\uc11c\ub294 \n4\uc6d4\uc5d0\ub294 \ubbf8\ub4dc, \uc601\ud654 \ubfd0 \uc544\ub2c8\ub77c \ucf54\ub85c\ub098 \ubc14\uc774\ub7ec\uc2a4\uc758 \uc704\uae30 \uc18d\uc5d0\uc11c \ub3c4\uc6c0\uc774 \ub418\ub294 \uc815\ubcf4\uc640 \uc548\uc815\uac10\uc744 \ub4dc\ub9ac\ub3c4\ub85d \ud558\uaca0\uc2b5\ub2c8\ub2e4. ","image":"http:\/\/img.podbbang.com\/pbi\/t\/430\/240\/0\/553\/041\/000041553\/41553.jpg","enclosure":{"type":"audio\/mpeg","url":"https:\/\/file.ssenhosting.com\/data1\/pb_22419\/watchthegrass.mp3","length":3476547},"duration":"00:03:37","cash":0,"like_count":6,"is_adult_only":false,"is_free":true,"is_paid":false,"can_download":true,"pay_method":"cash","sell_end_at":null,"published_at":"2020-04-01 07:30:00"},{"id":23448923,"podcast":{"id":16524},"title":"119\ud
2c8\ub2e4\uc694. \n\n*\uc601\uc5b4 \ubb38\uc7a5\n\uadf8\uac83\uc774 \uc6b0\ub9ac\ub97c \ud568\uaed8 \ud558\uac8c \ud588\ub2e4 That brought us together. \n\ub098\ub294 \uc0c1\ucc98(\uacb0\ud568)\uc774 \ub9ce\ub2e4. I have a lot of flaws. \n\n\n\uce74\ud1a1 \ucc44\ub110\uc5d0\uc11c \u2018\uc77c\uac04 \uc18c\uc6b8\uc601\uc5b4\u2019\ub97c \uac80\uc0c9\ud574\ubcf4\uc138\uc694. \n\uc601\uc5b4 \ucf58\ud150\uce20\ub294 \uc77 ...
# ------------
# <class 'dict'> {'data': [{'id': 23448927, 'podcast': {'id': 16524}, 'title': '120회 억지로 기분 나아지게 하지 맙시다', 'description': '짧은 영상이지만 도움되시길 바래봅니다. \n\n*영상으로 보시려면: https://www.youtube.com/channel/UCc-zCCulW6jq1lmWjlKCUkw\n\n\n*매일 아침 힘이되는 영어 공부 소울영어 구독: http://pf.kakao.com/_pxixkRxb\n아침 8시에 힘이 내는 3분 영어 콘텐츠를 보내드리는 일간 에서는 \n4월에는 미드, 영화 뿐 아니라 코로나 바이러스의 위기 속에서 도움이 되는 정보와 안정감을 드리도록 하겠습니다. ', 'image': 'http://img.podbbang.com/pbi/t/430/240/0/553/041/000041553/41553.jpg', 'enclosure': {'type': 'audio/mpeg', 'url': 'https://file.ssenhosting.com/data1/pb_22419/watchthegrass.mp3', 'length': 3476547}, 'duration': '00:03:37', 'cash': 0, 'like_count': 6, 'is_adult_only': False, 'is_free': True, 'is_paid': False, 'can_download': True, 'pay_method': 'cash', 'sell_end_at': None, 'published_at': '2020-04-01 07:30:00'}, {'id': 23448923, 'podcast': {'id': 16524}, 'title': '119회 한국 코로나 대응에 대한 외신 뉴스와 반응', 'description': '상황상 일간 소울영어 클립을 올려드립니다. \n아침 8시에 힘이 내는 3분 영어 콘텐츠를 보내드리는 일간 에서는 \n4월에는 미드, 영화 뿐 아니라 코로나 바이러스의 위기 속에서 도움이 되는 정보와 안정감을 드리도록 하겠습니다. \n\n*유튜브 영상으로 보시려면: https://www.youtube.com/channel/UCc-zCCulW6jq1lmWjlKCUkw\n*매일 아침 힘이되는 영어 공부 소울영어 구독: http://pf.kakao.com/_pxixkRxb\n\n여러분 다들 힘내시고, 곧 또 올리겠습니다!\n\n*오류 정정: 영상중 death toll은 사망자 수입니다. 사망률은 death rate입니다. \n ', 'image': 'http://img.podbbang.com/pbi/t/430/240/0/552/041/000041552/41552.jpg', 'enclosure': {'type': 'audio/mpeg', 'url': 'https://file.ssenhosting.com/data1/pb_22419/74overseasnews.mp3', 'length': 3971931}, 'duration': '00:04:08', 'cash': 0, 'like_count': 6, 'is_adult_only': False, 'is_free': True, 'is_paid': False, 'can_download': True, 'pay_method': 'cash', 'sell_end_at': None, 'published_at': '2020-03-30 13:18:20'}, {'id': 23400496, 'podcast': {'id': 16524}, 'title': '118회 이런 콜라보 웃음 폭탄, 영어 아웃 오브 안중 주의', 'description': '와 을 우리 맘대로 콜라보. \n잘가요. 이정혁 동지! 아듀!\n\n코로나로 다운된 기분 책임집니다요. \n\n*영어 문장\n그것이 우리를 함께 하게 했다 That brought us together. \n나는 상처(결함)이 많다. I have a lot of flaws. \n\n\n카톡 채널에서 ‘일간 소울영어’를 검색해보세요. \n영어 콘텐츠는 인터넷에 많은데 공부가 꾸준히 이어지는 것이 쉽지 않지요. 정말 필요한 건 대단한 영어 교재나 강의가 아니라 바로 꾸준함입니다. \n심리학을 전공한 영어강사 레바김이 매일 아침 8시 카톡으로 3분의 영어 스토리를 응원의 문자와 함께 보내드립니다. \n일간 소울영어는 영화와 각종 영상들의 영어 대사를 통해 마음챙김을 돕는 영어 구독 서비스입니다. 꾸역 꾸역하는 영어공부에 지치고 죄책감만 쌓이신다면 함께 하세요. \n월 구독료 1만원으로 나를 돌보는 하루가 시작됩니다. \n카톡채널 링크: \nhttp://pf.kakao.com/_pxixkRxb\n\n', 'image': 'http://img.podbbang.com/pbi/t/430/240/0/686/032/000032686/32686.jpg', 'enclosure': {'type': 'audio/mpeg', 'url': 'https://file.ssenhosting.com/data1/pb_22419/hand2020226.mp3', 'length': 15041739}, 'duration': '00:15:37', 'cash': 0, 'like_count': 14, 'is_adult_only': False, 'is_free': True, 'is_paid': False, 'can_download': True, 'pay_method': 'cash', 'sell_end_at': None, 'published_at': '2020-02-26 19:33:24'}, {'id': 23390572, 'podcast': {'id': 16524}, 'title': "117회 넷플릭스 본다면 이거슨 꿀팁 '나 홀로 그대' 공동구매각", 'description': "3일치 야근했을 일을 3시간만에 끝내는 AI 홀로그램 '홀로'\n넥플리스 신작  집중 토크, 홀로 사고 싶다는 이야기가 내용의 반이지만. 들어주세욤....\n\n1. 3일치 야근했을 일인데. \n2. 난 좀 당황스러워. \n3. 제가 기대치를 만족시키지 못했나요? \n4. 곧 익숙해지실 겁니다. \n\n여러분 홀로 사주세욤... \n", 'image': 'http://img.podbbang.com/pbi/t/430/240/0/120/031/000031120/31120.jpg', 'enclosure': {'type': 'audio/mpeg', 'url': 'https://file.ssenhosting.com/data1/pb_22419/handholo1.mp3', 'length': 18115751}, 'duration': '00:18:50', 'cash': 0, 'like_count': 15, 'is_adult_only': False, 'is_free': True, 'is_paid': False, 'can_download': True, 'pay_method': 'cash', 'sell_end_at': None, 'published_at': '2020-02-19 15:24:22'}, {'id': 23381234, 'podcast': {'id': 16524}, 'title': '116회 넌 라면먹을 계획이 다 있구나, 라끼남 맛 감탄을 영어로', 'description': '오너라면을 아시나요. \n오징어 + 너구리 조합에 감탄하는 강호동 맛 감탄사\n앞으로 라면 먹을 땐 반드시 머리 속에 이 표현 떠올리기!!!\n\nIt goes so well with 너구ri~\n', 'image': 'http://img.podbbang.com/pbi/t/430/240/0/572/029/000029572/29572.jpg', 'enclosure': {'type': 'audio/mpeg', 'url': 'https://file.ssenhosting.com/data1/pb_22419/hand2012.mp3', 'length': 10264144}, 'duration': '00:10:40', 'cash': 0, 'like_count': 10, 'is_adult_only': False, 'is_free': True, 'is_paid': False, 'can_download': True ...

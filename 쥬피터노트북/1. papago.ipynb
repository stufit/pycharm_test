# %%
## naver papago 서비스
##파이썬 기본 urllib 라이브러리 사용

# %%
import os
import sys
import urllib.request
client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
encText = urllib.parse.quote("Yesterday all my troubles seemed so far away")
data = "source=en&target=ko&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"어제 나의 모든 고민들은 너무나 멀리 있는 것 같았다.","engineType":"N2MT","pivot":null}}}

# %%
##requests 라이브러리를 사용

# %%
import requests

client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
enc_text = "Yesterday all my troubles seemed so far away"
url = "https://openapi.naver.com/v1/papago/n2mt"


#request hearder 값 선언
req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
}
#request form data 값 선언
req_data = {
        "source":"en",
        "target":"zh-CN",
        "text":enc_text
}
#request 보내기(post 함수 호출)
res = requests.post(url, data=req_data, headers=req_header)


print(type(res))
print(res.status_code,res.ok)
print('응답헤더',res.headers)
print('요청해더',res.request.headers)
# Out:
# <class 'requests.models.Response'>
# 200 True
# 응답헤더 {'Server': 'nginx', 'Date': 'Thu, 15 Oct 2020 06:05:15 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '221', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=5', 'X-QUOTA': '44', 'Content-Encoding': 'gzip'}
# 요청해더 {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'X-Naver-Client-Id': '4iBXcD6XQHjxnLfcYoVU', 'X-Naver-Client-Secret': 'JaaIoTbm49', 'Content-Length': '72', 'Content-Type': 'application/x-www-form-urlencoded'}

# %%
if res.ok:
    print(type(res.text))
    print('응답 Text',res.text)
else:
    print('Status Code :',res.status_code)
# Out:
# <class 'str'>
# 응답 Text {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"어제 나의 모든 고민들은 너무나 멀리 떨어져 있는 것 같았다.","engineType":"N2MT","pivot":null}}}

# %%
if res.ok:
    result_json = res.json()
    print(type(result_json))
    print(result_json)
# Out:
# <class 'dict'>
# {'message': {'@type': 'response', '@service': 'naverservice.nmt.proxy', '@version': '1.0.0', 'result': {'srcLangType': 'en', 'tarLangType': 'zh-CN', 'translatedText': '昨天,我所有的烦恼似乎都离我太远了。', 'engineType': 'N2MT', 'pivot': None}}}

# %%
print(result_json['message']['result']['translatedText'])
# Out:
# 昨天,我所有的烦恼似乎都离我太远了。

# %%
###네이버 검색 서비스

import os
import sys
import urllib.request
client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
encText = urllib.parse.quote("빅데이터파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 15 Oct 2020 15:20:15 +0900",
# "total": 19435,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>빅데이터</b> 분석 위한 <b>파이썬</b> 입문 클룸에서 즐겁게",
# "link": "https:\/\/blog.naver.com\/sweetk2ss?Redirect=Log&logNo=222020792291",
# "description": "부상한 <b>파이썬</b>은 높은 수준의 <b>데이터</b> 구조를 가지고 있으면서도 이해하기 쉬운 간결성을 지니고 있어서... 급변하는 세상 속에서 방대하게 쌓이는 <b>데이터</b>로 인해 <b>빅데이터</b> 분석의 중요성은 날이 갈수록 커지고... ",
# "bloggername": "도찌의블로그",
# "bloggerlink": "https://blog.naver.com/sweetk2ss",
# "postdate": "20200704"
#
# },
# {
# "title": "<b>빅데이터 파이썬</b> 크롤링을 활용한 분석(+취업)",
# "link": "https:\/\/blog.naver.com\/mailkkw4?Redirect=Log&logNo=222079924550",
# "description": "등장도 <b>빅데이터 파이썬</b>과 밀접환 연관을 가지고 있습니다. #파이썬크롤링 가장 수요가 많은 이유... 관련된 빅데이터를 파이썬 크롤링 작업을 통하여 신청자의 평판에 대한 데이터를 분석하여 신용을... ",
# "bloggername": "월화수목금퇼!!",
# "bloggerlink": "https://blog.naver.com/mailkkw4",
# "postdate": "20200904"
#
# },
# {
# "title": "<b>파이썬</b> 학원 후기, <b>빅데이터</b> 과정 수강하고 있는 이유는?",
# ...

# %%
import requests

client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
enc_text = "빅데이터파이썬"
url = "https://openapi.naver.com/v1/search/blog"


#request hearder 값 선언
req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
}
#request form data 값 선언
req_data = {
        "query":"python",
        "text":enc_text
}
#request 보내기(post 함수 호출)
res = requests.get(url, params=req_data, headers=req_header)


print(type(res))
print(res.status_code,res.ok)
print('응답헤더',res.headers)
print('요청해더',res.request.headers)
# Out:
# <class 'requests.models.Response'>
# 200 True
# 응답헤더 {'Server': 'nginx', 'Date': 'Thu, 15 Oct 2020 06:23:04 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '2475', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=5', 'x-rate-limit': '10', 'x-rate-limit-remaining': '9', 'x-rate-limit-reset': '1602742985000', 'X-Powered-By': 'Naver', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip'}
# 요청해더 {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'X-Naver-Client-Id': '4iBXcD6XQHjxnLfcYoVU', 'X-Naver-Client-Secret': 'JaaIoTbm49'}

# %%
if res.ok:
    result_json = res.json()
    print(type(result_json))
    print(result_json)
# Out:
# <class 'dict'>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-f508850df6ff> in <module>
# ----> 1 print(result_json['message']['result']['translatedText'])
#
# KeyError: 'message'

# %%
import requests

client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
url = "https://openapi.naver.com/v1/search/blog"


#request hearder 값 선언
req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
}
#request form data 값 선언
req_data = {
        "query":"이관영"     
}
#request 보내기(post 함수 호출)
res = requests.get(url, params=req_data, headers=req_header)


print(type(res))
print(res.status_code,res.ok)
print('응답헤더',res.headers)
print('요청해더',res.request.headers)
# Out:
# <class 'requests.models.Response'>
# 200 True
# 응답헤더 {'Server': 'nginx', 'Date': 'Thu, 15 Oct 2020 06:24:17 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '2336', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=5', 'x-rate-limit': '10', 'x-rate-limit-remaining': '9', 'x-rate-limit-reset': '1602743058000', 'X-Powered-By': 'Naver', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip'}
# 요청해더 {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'X-Naver-Client-Id': '4iBXcD6XQHjxnLfcYoVU', 'X-Naver-Client-Secret': 'JaaIoTbm49'}

# %%
if res.ok:
    result_json = res.json()
    print(type(result_json))
    print(result_json)
# Out:
# <class 'dict'>
# ...

# %%
import requests

client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
url = "https://openapi.naver.com/v1/search/blog"


#request hearder 값 선언
req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
}
#request form data 값 선언
req_params = {
        "query":"이관영"     
}
#request 보내기(post 함수 호출)
res = requests.get(url, params=req_params, headers=req_header)


print(type(res))
print(res.status_code,res.ok)
print('응답헤더',res.headers)
print('요청해더',res.request.headers)
# Out:
# <class 'requests.models.Response'>
# 200 True
# 응답헤더 {'Server': 'nginx', 'Date': 'Thu, 15 Oct 2020 06:43:02 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '2336', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=5', 'x-rate-limit': '10', 'x-rate-limit-remaining': '9', 'x-rate-limit-reset': '1602744183000', 'X-Powered-By': 'Naver', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip'}
# 요청해더 {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'X-Naver-Client-Id': '4iBXcD6XQHjxnLfcYoVU', 'X-Naver-Client-Secret': 'JaaIoTbm49'}

# %%
if res.ok:
    result_json = res.json()
    print(result_json)
# Out:
# {'lastBuildDate': 'Thu, 15 Oct 2020 15:24:31 +0900', 'total': 1925, 'start': 1, 'display': 10, 'items': [{'title': '인제대학교 금형·신소재공학과 <b>이관영</b> 금형명장, 차세대... ', 'link': 'https://blog.naver.com/dkdrkwl?Redirect=Log&logNo=221371432978', 'description': '▲인제대학교 금형·신소재공학과 금형명장 <b>이관영</b> 학과장 시사투데이 박미라 기자] 금형은... 바로 이 점에서 금형명장(2013년)이자 인제대학교 금형·신소재공학과 <b>이관영</b> 학과장의 행보가 단연 눈길을 끈다.... ', 'bloggername': '박 기자가 그리는 세상♥', 'bloggerlink': 'https://blog.naver.com/dkdrkwl', 'postdate': '20181005'}, {'title': '[티앤씨재단]10월 비전렉처_과학기술_<b>이관영</b>교수님', 'link': 'https://blog.naver.com/happydoo9133?Redirect=Log&logNo=221689581983', 'description': '연사님 : <b>이관영</b> 교수님 출처 : 네이버 인물 정보 오늘의 연사님은 <b>이관영</b> 교수님이셨다. 우리 학교의 화공 교수님이시자 염총장님 계실 때까지 연구부 총장을 역임하셨다고 한다. 공학, 특히 화학 공학쪽에서... ', 'bloggername': '두-로그', 'bloggerlink': 'https://blog.naver.com/happydoo9133', 'postdate': '20191026'}, {'title': '[T&amp;C VISION LECTURE] 고려대 화공생명공학과 <b>이관영</b>... ', 'link': 'https://blog.naver.com/tnc2018?Redirect=Log&logNo=221694
# ...

# %%
#선생님이 하신 코드
import requests

keyword = "파이썬"
client_id = "4iBXcD6XQHjxnLfcYoVU"
client_secret = "JaaIoTbm49"
url = "https://openapi.naver.com/v1/search/blog"

#request header
req_header ={
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
}

#request form
req_data ={
        "query":keyword
}

#request 보내기
res = requests.get(url, params=req_data,headers=req_header)
print(res.status_code, res.ok)
# Out:
#   File "<ipython-input-109-4f96909eee46>", line 7
#     keyword=
#             ^
# SyntaxError: invalid syntax

# %%
def search_service(keyword,displaycount):
    
    client_id = "4iBXcD6XQHjxnLfcYoVU"
    client_secret = "JaaIoTbm49"
    url = "https://openapi.naver.com/v1/search/blog.json"

    #request header
    req_header ={
            "X-Naver-Client-Id":client_id,
            "X-Naver-Client-Secret":client_secret
    }

    #request form
    req_data ={
            "query":keyword,
            "display":displaycount
}
    res = requests.get(url, params=req_data,headers=req_header)
    print(res.status_code, res.ok)
    #print(res.text)
    json_data =res.json()
    print(type(json_data['items']))
    item_list = json_data['items']
    print(len(json_data['items']))
    
    result_list = []
    for item in item_list:
        print(type(item))
       # print(item)
        result_list.append(item)
    return result_list
        
search_service("자바",2)
# Out:
# 200 True
# <class 'list'>
# 2
# <class 'dict'>
# <class 'dict'>
# [{'title': '<b>자바</b> 파이썬 입문 언어 승자는?',
#   'link': 'https://blog.naver.com/skh556?Redirect=Log&logNo=222038807263',
#   'description': '그중에서도 우선순위 1순위, 2순위를 다투는 <b>자바</b> 파이썬 비교 분석을 하는 포스팅을 하려고 합니다.... &lt; 출처 : 오라클 홈페이지 &gt; <b>자 바</b> <b>자바</b>는 1995년 썬 마이크로시스템즈라는 회사에서 개발한 객체지향... ',
#   'bloggername': '우렁찬한우의 힘찬 블로그',
#   'bloggerlink': 'https://blog.naver.com/skh556',
#   'postdate': '20200723'},
#  {'title': '<b>자바</b>학원 늦지 않았더라고요~',
#   'link': 'https://blog.naver.com/yosuleye?Redirect=Log&logNo=222095672833',
#   'description': '걸리는게 많아서 2~3년의 경력을 쌓고 그 후에는 프리랜서로 활동을 하고 싶다는 생각을 갖고 <b>자바</b>학원... 그래서 <b>자바</b>학원을 알아보는데는 어려움이 없었어요. 근데 막상 시작하기 전에 잘한걸까? 여기... ',
#   'bloggername': 'yosuleye님의 블로그',
#   'bloggerlink': 'https://blog.naver.com/yosuleye',
#   'postdate': '20200921'}]

# %%
my_list = search_service('파이썬',3)
print(my_list)
# Out:
# 200 True
# <class 'list'>
# 3
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...

# %%
def search_service(keyword,displaycount,kind):
    
    client_id = "4iBXcD6XQHjxnLfcYoVU"
    client_secret = "JaaIoTbm49"
    url = f"https://openapi.naver.com/v1/search/{kind}.json"

    #request header
    req_header ={
            "X-Naver-Client-Id":client_id,
            "X-Naver-Client-Secret":client_secret
    }

    #request form
    req_data ={
            "query":keyword,
            "display":displaycount
}
    res = requests.get(url, params=req_data,headers=req_header)
   # print(res.status_code, res.ok)
    #print(res.text)
    json_data =res.json()
    #print(type(json_data['items']))
    item_list = json_data['items']
   # print(len(json_data['items']))
    
    result_list = []
    for item in item_list:
        #print(type(item))
       # print(item)
        result_list.append(item)
    return result_list
        
search_service("자바",2,'news')
# Out:
# [{'title': '코로나 사태 속에서도 한국-인도네시아 비대면 문화 교류 꽃이 피다',
#   'originallink': 'http://www.civicnews.com/news/articleView.html?idxno=29949',
#   'link': 'http://www.civicnews.com/news/articleView.html?idxno=29949',
#   'description': '치레본 시가 한국의 ODA 지원 대상으로 선정된 이유는 이 도시가 중국, 네덜란드, <b>자바</b>, 순다 등의 문화가 혼합되어 있는\xa0독특하고 강한 전통을 가진 곳이기 때문이다. 치레본 시는 <b>자바</b> 섬 서쪽에 있는 항만... ',
#   'pubDate': 'Thu, 15 Oct 2020 17:12:00 +0900'},
#  {'title': "한국도로공사, 조폐공사 등 주요 공공기관 이달 신입 채용 '활발'",
#   'originallink': 'http://news.unn.net/news/articleView.html?idxno=235720',
#   'link': 'http://news.unn.net/news/articleView.html?idxno=235720',
#   'description': '△블록체인연구 △백엔드 △모바일 △시스템엔지니어 △클라이언트(<b>자바</b>, C#) △정보보안 등 다양한 IT분야에서 신입사원을 뽑는다. 서류전형과 코딩테스트, 인성검사, 면접시험 등을 통해 채용형 인턴을 선발하고, 이후... ',
#   'pubDate': 'Thu, 15 Oct 2020 14:23:00 +0900'}]

# %%
result_list = search_service('머신러닝',3,'book')
for result in result_list:
    print(result)
# Out:
# {'title': '핸즈온 <b>머신러닝</b>(2판) (사이킷런, 케라스, 텐서플로 2를 활용한 <b>머신러닝</b>, 딥러닝 완벽 실무)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=16328592', 'image': 'https://bookthumb-phinf.pstatic.net/cover/163/285/16328592.jpg?type=m1&udate=20201005', 'author': '오렐리앙 제롱', 'price': '55000', 'discount': '49500', 'publisher': '한빛미디어', 'pubdate': '20200504', 'isbn': '1162242965 9791162242964', 'description': '컬러판으로 돌아온 아마존 인공지능 분야 부동의 1위 도서\n이 책은 지능형 시스템을 구축하려면 반드시 알아야 할 <b>머신러닝</b>, 딥러닝 분야 핵심 개념과 이론을 이해하기 쉽게 설명한다. 사이킷런, 케라스, 텐서플로를 이용해 실전에서 바로 활용 가능한 예제로 모델을 훈련하고 신경망을 구축하는 방법을... '}
# ...

# %%
kind_list = ['blog','movie','book']
for kind in kind_list:
    print(f'>>>분야:{kind}')
    for item in search_service('딥러닝',2,kind):
        print(item)
# Out:
# >>>분야:blog
# {'title': '인공지능(<b>딥러닝</b>)의 정의와 사례', 'link': 'https://blog.naver.com/infopub?Redirect=Log&logNo=222114155013', 'description': '이에는 머신러닝, <b>딥러닝</b>이 모두 포함돼 있습니다. 그중에서도 우리는 인공지능의 획기적인 발전을 이끈 <b>딥러닝</b>에 대해 자세히 알아보겠습니다. 또한 <b>딥러닝</b>은 무엇이고 그 종류에는 어떤 것이... ', 'bloggername': 'IT 서적의 명가', 'bloggerlink': 'https://blog.naver.com/infopub', 'postdate': '20201013'}
# {'title': '이해 #1 – 주요 역사와 개념 정리(feat. 머신러닝, <b>딥러닝</b>)', 'link': 'https://blog.naver.com/skinfosec2000?Redirect=Log&logNo=222029239340', 'description': '오늘은 4차 산업혁명 시대의 핵심 기술이라 불리는 인공지능의 주요 역사와 특징 그리고 머신러닝과 <b>딥러닝</b>의 차이에 대해 알아보겠습니다. ‘인공지능(AI, Artificial Intelligence)’이란? 인공지능은... ', 'bloggername': 'SK인포섹(주) 공식블로그', 'bloggerlink': 'https://blog.naver.com/skinfosec2000', 'postdate': '20200713'}
# >>>분야:movie
# >>>분야:book
# ...

# %% [markdown]
# ###papago 서비스 사용
#     * yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
#     * list에 있는 내용을 번역 서비스 요청
#     * 서비스 응답 결과를 다시 파일에 저장을 함

# %%
import requests

def translyric_savefiles(trans_list):
    with open('data/yesterday_trans.txt','w') as file:
        file.writelines(trans_list)

#yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
def get_text_savelist():
    lyric_list=[]
    with open('data/yesterday.txt','r',encoding='utf-8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list
    print(lyric_list)



def main():
    client_id = "yodEzRY_poUH1ig1hevT"
    client_secret = "azd_Ofrf8d"
    url = "https://openapi.naver.com/v1/papago/n2mt"


    #request hearder 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = get_text_savelist()
    lyric_list = [lyric for lyric in lyric_list if len(lyric) !=0]
    print(len(lyric_list))
    
    trans_list =[]
    print('>>>번역시작')
    for req_lyric in lyric_list:
        print(req_lyric)
        
        #request form data 값 선언
        req_data = {
            "source":"en",
            "target":"ko",
            "text":req_lyric
        }
        #papago 서비스요청, post()함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        print(res.status_code)
        try:
            trans_lyric = res.json()['message']['result']['translatedText']
        except Exception as exp:
            print(exp)
        else:
            print(trans_lyric)
        trans_list.append(req_lyric+'\n')
        trans_list.append(trans_lyric+'\n')
        
    translyric_savefiles(trans_list)
    print('>>>번역종료')
main()
# Out:
# 17
# >>>번역시작
# Yesterday all my troubles seemed so far away.
# 200
# 어제 나의 모든 고민들은 너무나 멀리 떨어져 있는 것 같았다.
# Now it looks as though they're here to stay.
# 200
# 이제 그들은 여기 머물기 위해 온 것처럼 보인다.
# Oh, I believe in yesterday.
# 200
# 오, 나는 어제를 다시 그리게 돼.
# Suddenly I'm not half the man I used to be.
# 200
# 갑자기 나는 예전과 같은 사람이 아니다.
# There's a shadow hanging over me.
# 200
# 내 위에 그림자가 드리워져 있다.
# Oh, yesterday came suddenly.
# 200
# 아, 어제 갑자기 왔구나.
# Why she had to go, I don't know, she wouldn't say.
# 200
# 왜 그녀가 가야만 했는지 모르겠다, 그녀는 말하지 않을 것이다.
# I said something wrong, now I long for yesterday.
# 200
# 내가 말을 잘못해서 어제가 그립다.
# Yesterday love was such an easy game to play.
# 200
# 어제는 사랑이 정말 쉬운 게임이었다.
# Now I need a place to hide away.
# 200
# 이제 나는 숨을 곳이 필요해.
# Oh, I believe in yesterday.
# 200
# 오, 나는 어제를 다시 그리게 돼.
# Why she had to go, I don't know, she wouldn't say.
# 200
# 왜 그녀가 가야만 했는지 모르겠다, 그녀는 말하지 않을 것이다.
# I said something wrong, now I long for yesterday.
# 200
# 내가 말을 잘못해서 어제가 그립다.
# ...

# %%
import requests

# def translyric_savefiles(trans_list):
#     with open('data/goback.txt','w') as file:
#         file.writelines(trans_list)

#yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
def savelist():
    lyric_list=[]
    with open('data/goback.txt','r',encoding='utf-8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list
    print(lyric_list)



def main():
    client_id = "yodEzRY_poUH1ig1hevT"
    client_secret = "azd_Ofrf8d"
    url = "https://openapi.naver.com/v1/papago/n2mt"


    #request hearder 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = savelist()
    lyric_list = [lyric for lyric in lyric_list if len(lyric) !=0]
    print(len(lyric_list))
    
    trans_list =[]
    print('>>>번역시작')
    for req_lyric2 in lyric_list:
        print(req_lyric2)
        
        #request form data 값 선언
        req_data = {
            "source":"zh-cn",
            "target":"ko",
            "text":req_lyric2
        }
        #papago 서비스요청, post()함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        print(res.status_code)
        try:
            trans_lyric2 = res.json()['message']['result']['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric2)
        trans_list.append(req_lyric2)
        
        
   
    print('>>>번역종료')
main()
# Out:
# 30
# >>>번역시작
# 塞纳河畔 左岸的咖啡
# 400
# 400
# 我手一杯 品尝你的美 留下唇印的嘴
# 400
# 400
# 花店玫瑰 名字写错谁
# 400
# 400
# 告白气球 风吹到对街 微笑在天上飞
# 400
# 400
# 你说你有点难追 想让我知难而退
# 400
# 400
# 礼物不需挑最贵 只要香榭的落叶
# 400
# 400
# 营造浪漫的约会 不害怕搞砸一切
# 400
# 400
# 拥有你就拥有 全世界
# 400
# 400
# 亲爱的 爱上你
# 400
# 400
# 从那天起 甜蜜的很轻易
# 400
# 400
# 亲爱的 别任性
# 400
# 400
# 你的眼睛 在说我愿意
# 400
# 400
# 塞纳河畔 左岸的咖啡
# 400
# 400
# 我手一杯 品尝你的美 留下唇印的嘴
# 400
# 400
# 花店玫瑰 名字写错谁
# 400
# 400
# 告白气球 风吹到对街 微笑在天上飞
# 400
# 400
# 你说你有点难追 想让我知难而退
# 400
# 400
# 礼物不需挑最贵 只要香榭的落叶
# 400
# 400
# 营造浪漫的约会 不害怕搞砸一切
# 400
# 400
# 拥有你就拥有 全世界
# 400
# 400
# 亲爱的 爱上你
# 400
# 400
# 从那天起 甜蜜的很轻易
# 400
# 400
# 亲爱的 别任性
# 400
# 400
# 你的眼睛 在说我愿意
# 400
# 400
# 亲爱的 爱上你
# 400
# 400
# 恋爱日记 飘香水的回忆
# 400
# 400
# 一整瓶 的梦境
# 400
# 400
# 全都有你 搅拌在一起
# 400
# 400
# 亲爱的 别任性
# 400
# 400
# 你的眼睛 在说我愿意
# 400
# 400
# >>>번역종료

# %%
import requests

# def translyric_savefiles(trans_list):
#     with open('data/yesterday_trans.txt','w') as file:
#         file.writelines(trans_list)

#yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
def get_text_savelist():
    lyric_list=[]
    with open('data/uptown.txt','r',encoding='utf-8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list
    print(lyric_list)



def main():
    client_id = "yodEzRY_poUH1ig1hevT"
    client_secret = "azd_Ofrf8d"
    url = "https://openapi.naver.com/v1/papago/n2mt"


    #request hearder 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = get_text_savelist()
    lyric_list = [lyric for lyric in lyric_list if len(lyric) !=0]
    print(len(lyric_list))
    
    trans_list =[]
    print('>>>번역시작')
    for req_lyric in lyric_list:
        print(req_lyric)
        
        #request form data 값 선언
        req_data = {
            "source":"en",
            "target":"ko",
            "text":req_lyric
        }
        #papago 서비스요청, post()함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        print(res.status_code)
        try:
            trans_lyric = res.json()['message']['result']['translatedText']
        except Exception as exp:
            print(exp)
        else:
            print(trans_lyric)
        trans_list.append(req_lyric+'\n')
        trans_list.append(trans_lyric+'\n')
        
    translyric_savefiles(trans_list)
    print('>>>번역종료')
main()
# Out:
# 100
# >>>번역시작
# This hit, that ice cold
# 429
# 'message'
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-217-20bddf664f41> in <module>
#      57     translyric_savefiles(trans_list)
#      58     print('>>>번역종료')
# ---> 59 main()
#
# <ipython-input-217-20bddf664f41> in main()
#      53             print(trans_lyric)
#      54         trans_list.append(req_lyric+'\n')
# ---> 55         trans_list.append(trans_lyric+'\n')
#      56
#      57     translyric_savefiles(trans_list)
#
# UnboundLocalError: local variable 'trans_lyric' referenced before assignment

# %%
import requests

def translyric_savefiles(trans_list,song_name):
    with open(f'data/{song_name}_trans.txt','w') as file:
        file.writelines(trans_list)

#yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
def get_text_savelist(song_name):
    file_name = f'data/{song_name}.txt'
    lyric_list=[]
    with open(file_name,'r',encoding='utf-8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list
    print(lyric_list)



def main(song_name):
    client_id = "4iBXcD6XQHjxnLfcYoVU"
    client_secret = "JaaIoTbm49"
    url = "https://openapi.naver.com/v1/papago/n2mt"


    #request hearder 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = get_text_savelist(song_name)
    lyric_list = [lyric for lyric in lyric_list if len(lyric) !=0]
    print(len(lyric_list))
    
    trans_list =[]
    print('>>>번역시작')
    for req_lyric in lyric_list:
        print(req_lyric)
        
        #request form data 값 선언
        req_data = {
            "source":"en",
            "target":"ko",
            "text":req_lyric
        }
        #papago 서비스요청, post()함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        print(res.status_code)
        try:
            trans_lyric = res.json()['message']['result']['translatedText']
            trans_list.append(req_lyric+'\n')
            trans_list.append(trans_lyric+'\n')
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
#         trans_list.append(req_lyric+'\n')
#         trans_list.append(trans_lyric+'\n')
        
    translyric_savefiles(trans_list,song_name)
    print('>>>번역종료')
main('uptown')
# Out:
# 100
# >>>번역시작
# This hit, that ice cold
# 200
# 이 히트, 저 얼음냉이
# Michelle Pfeiffer, that white gold
# 200
# 미셸 파이퍼, 저 하얀 금.
# This one for them hood girls
# 200
# 이건 후드집업 여자애들을 위한거야
# Them good girls straight masterpieces
# 200
# 저 착한 소녀들은 걸작들을 곧게
# Stylin', wilin', livin' it up in the city
# 200
# 스타일린, 윌린, 도시에 살고 있어
# Got Chucks on with Saint Laurent
# 200
# 생로랑 척스랑 사귀고 있어
# Gotta kiss myself, I'm so pretty
# 200
# 키스해야겠다, 나 너무 예뻐.
# I'm too hot (hot damn)
# 200
# 나 너무 더워 (뜨거워)
# Called a police and a fireman
# 200
# 경찰과 소방관을 불렀다.
# I'm too hot (hot damn)
# 200
# 나 너무 더워 (뜨거워)
# Make a dragon wanna retire man
# 200
# 용을 만들고 은퇴하고 싶다.
# I'm too hot (hot damn)
# 200
# 나 너무 더워 (뜨거워)
# Say my name you know who I am
# 200
# 내 이름을 말해줘 내가 누군지 알잖아
# I'm too hot (hot damn)
# 200
# 나 너무 더워 (뜨거워)
# And my band 'bout that money, break it down
# 200
# 그리고 내 밴드는 그 돈을 부숴버려.
# Girls hit your hallelujah (whoo)
# 200
# 여자애들은 너의 할렐루야를 때린다 (후우)
# Girls hit your hallelujah (whoo)
# 200
# ...

# %%
import requests

def savedlyric():
    lyric_list1=[]
    with open('data/uptown.txt', 'r', encoding='utf-8') as file:
        contents = file.contents()
        lyric_list1 = contents.split('\n')
    return lyric_list1
    print(lyric_list1)

def main():
    client_id = "yodEzRY_poUH1ig1hevT"
    client_secret = "azd_Ofrf8d"
    url = "https://openapi.naver.com/v1/papago/n2mt"
    
     #request hearder 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list1 = savelyric()
    lyric_list1 = [lyric for lyric in lyric_list1 if len(lyric) !=0]
    print(len(lyric_list1))
    
    trans_list =[]
    print('>>>번역시작')
    for req_lyric in lyric_list1:
        print(req_lyric)
        
    #request form data 값 선언
        req_data = {
            "source":"en",
            "target":"ko",
            "text":req_lyric
